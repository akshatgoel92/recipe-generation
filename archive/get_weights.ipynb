# %%
# Install these packages with these specific versions else the notebook breaks
# !pip install transformers==4.5.1
# !pip install pytorch_lightning==1.2.10
# !pip install sentencepiece
# Out:
# Collecting transformers==4.5.1
#   Using cached transformers-4.5.1-py3-none-any.whl (2.1 MB)
# Collecting tokenizers<0.11,>=0.10.1
#   Using cached tokenizers-0.10.2-cp38-cp38-macosx_10_11_x86_64.whl (2.3 MB)
# Requirement already satisfied: numpy>=1.17 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from transformers==4.5.1) (1.19.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from transformers==4.5.1) (2021.4.4)
# Requirement already satisfied: packaging in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from transformers==4.5.1) (20.4)
# Requirement already satisfied: filelock in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from transformers==4.5.1) (3.0.12)
# Requirement already satisfied: sacremoses in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from transformers==4.5.1) (0.0.45)
# Requirement already satisfied: tqdm>=4.27 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from transformers==4.5.1) (4.59.0)
# Requirement already satisfied: requests in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from transformers==4.5.1) (2.24.0)
# Requirement already satisfied: six in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from packaging->transformers==4.5.1) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from packaging->transformers==4.5.1) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from requests->transformers==4.5.1) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from requests->transformers==4.5.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from requests->transformers==4.5.1) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from requests->transformers==4.5.1) (2.10)
# Requirement already satisfied: click in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from sacremoses->transformers==4.5.1) (7.1.2)
# Requirement already satisfied: joblib in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from sacremoses->transformers==4.5.1) (0.17.0)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.7.0
#     Uninstalling tokenizers-0.7.0:
#       Successfully uninstalled tokenizers-0.7.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 2.9.0
#     Uninstalling transformers-2.9.0:
#       Successfully uninstalled transformers-2.9.0
# Successfully installed tokenizers-0.10.2 transformers-4.5.1
# Collecting pytorch_lightning==1.2.10
#   Downloading pytorch_lightning-1.2.10-py3-none-any.whl (841 kB)
#      |████████████████████████████████| 841 kB 6.2 MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=4.41.0 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from pytorch_lightning==1.2.10) (4.59.0)
# Collecting tensorboard!=2.5.0,>=2.2.0
#   Downloading tensorboard-2.4.1-py3-none-any.whl (10.6 MB)
#      |████████████████████████████████| 10.6 MB 5.9 MB/s eta 0:00:01
# Requirement already satisfied: torch>=1.4 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from pytorch_lightning==1.2.10) (1.7.0)
# Collecting fsspec[http]>=0.8.1
#   Downloading fsspec-2021.5.0-py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 6.4 MB/s eta 0:00:01
# Collecting PyYAML!=5.4.*,>=5.1
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
#      |████████████████████████████████| 269 kB 6.2 MB/s eta 0:00:01
# Collecting torchmetrics==0.2.0
#   Downloading torchmetrics-0.2.0-py3-none-any.whl (176 kB)
#      |████████████████████████████████| 176 kB 9.7 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from pytorch_lightning==1.2.10) (20.4)
# Requirement already satisfied: future>=0.17.1 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from pytorch_lightning==1.2.10) (0.18.2)
# Requirement already satisfied: numpy>=1.16.6 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from pytorch_lightning==1.2.10) (1.19.2)
# Collecting aiohttp
#   Downloading aiohttp-3.7.4.post0-cp38-cp38-macosx_10_14_x86_64.whl (648 kB)
#      |████████████████████████████████| 648 kB 7.2 MB/s eta 0:00:01     |████████████████████████▊       | 501 kB 7.2 MB/s eta 0:00:01
# Requirement already satisfied: requests in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (2.24.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (3.3.4)
# Requirement already satisfied: six>=1.10.0 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (1.15.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (0.4.4)
# Requirement already satisfied: absl-py>=0.4 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (0.12.0)
# Requirement already satisfied: protobuf>=3.6.0 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (3.15.8)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (54.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (1.8.0)
# Requirement already satisfied: wheel>=0.26 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (0.36.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (1.30.0)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (1.37.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from requests->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from requests->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from requests->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from requests->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (3.1.0)
# Requirement already satisfied: typing-extensions in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from torch>=1.4->pytorch_lightning==1.2.10) (3.7.4.3)
# Requirement already satisfied: dataclasses in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from torch>=1.4->pytorch_lightning==1.2.10) (0.6)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp38-cp38-macosx_10_14_x86_64.whl (124 kB)
#      |████████████████████████████████| 124 kB 6.9 MB/s eta 0:00:01
# Requirement already satisfied: attrs>=17.3.0 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from aiohttp->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (20.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp38-cp38-macosx_10_14_x86_64.whl (49 kB)
#      |████████████████████████████████| 49 kB 6.7 MB/s  eta 0:00:01
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (from packaging->pytorch_lightning==1.2.10) (2.4.7)
# Building wheels for collected packages: PyYAML
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp38-cp38-macosx_10_15_x86_64.whl size=44624 sha256=13c6a678e5f473ab49698754fa50d6747359811095d065d66e6fa31e29e062c5
#   Stored in directory: /Users/akshatgoel/Library/Caches/pip/wheels/13/90/db/290ab3a34f2ef0b5a0f89235dc2d40fea83e77de84ed2dc05c
# Successfully built PyYAML
# Installing collected packages: multidict, yarl, async-timeout, fsspec, aiohttp, torchmetrics, tensorboard, PyYAML, pytorch-lightning
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.5.0
#     Uninstalling tensorboard-2.5.0:
#       Successfully uninstalled tensorboard-2.5.0
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 0.7.5
#     Uninstalling pytorch-lightning-0.7.5:
#       Successfully uninstalled pytorch-lightning-0.7.5
# Successfully installed PyYAML-5.3.1 aiohttp-3.7.4.post0 async-timeout-3.0.1 fsspec-2021.5.0 multidict-5.1.0 pytorch-lightning-1.2.10 tensorboard-2.4.1 torchmetrics-0.2.0 yarl-1.6.3
# Requirement already satisfied: sentencepiece in /Users/akshatgoel/.pyenv/versions/3.8.0/envs/intro-dl-env/lib/python3.8/site-packages (0.1.95)

# %%
# Import packages
import argparse
import glob
import pickle
import os
import json
import time
import logging
import random
import re
from tqdm import tqdm
from itertools import chain
from string import punctuation
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu

import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize


import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl
import sentencepiece


from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup
)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/akshatgoel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
class T5FineTuner(pl.LightningModule):
  def __init__(self, hparams):
    super(T5FineTuner, self).__init__()
    
    if type(hparams) is dict: 
      hparams = argparse.Namespace(**hparams)
    
    self.hparams = hparams
    self.model = T5ForConditionalGeneration.from_pretrained(hparams.model_name_or_path)
    self.tokenizer = T5Tokenizer.from_pretrained(hparams.tokenizer_name_or_path)
  
  def is_logger(self):
    return self.trainer.global_rank <= 0
  
  def forward(
      self, input_ids, attention_mask=None, decoder_input_ids=None, decoder_attention_mask=None, labels=None
  ):
    return self.model(
        input_ids,
        attention_mask=attention_mask,
        decoder_input_ids=decoder_input_ids,
        decoder_attention_mask=decoder_attention_mask,
        labels=labels,
    )

  def _step(self, batch):
    labels = batch["target_ids"]
    labels[labels[:, :] == self.tokenizer.pad_token_id] = -100

    outputs = self(
        input_ids=batch["source_ids"],
        attention_mask=batch["source_mask"],
        labels=labels,
        decoder_attention_mask=batch['target_mask']
    )

    loss = outputs[0]
    
    return loss

  def training_step(self, batch, batch_idx):
    loss = self._step(batch)
    self.log('training_loss', loss, on_step=True, on_epoch=True, prog_bar=True, logger=True)
    tensorboard_logs = {"train_loss": loss}
    return {"loss": loss, "log": tensorboard_logs}
  
  def training_epoch_end(self, outputs):
    avg_train_loss = torch.stack([x["loss"] for x in outputs]).mean()
    self.log('avg_training_loss', avg_train_loss, on_step=False, on_epoch=True, prog_bar=True, logger=True)
    tensorboard_logs = {"avg_train_loss": avg_train_loss}
    return {"avg_train_loss": avg_train_loss, "log": tensorboard_logs, 'progress_bar': tensorboard_logs}

  def validation_step(self, batch, batch_idx):
    loss = self._step(batch)
    self.log('val_loss', loss, on_step=False, on_epoch=True, prog_bar=True, logger=True)
    tensorboard_logs = {"val_loss": loss}
    return {"val_loss": loss, "log": tensorboard_logs}
  
  def validation_epoch_end(self, outputs):
    avg_loss = torch.stack([x["val_loss"] for x in outputs]).mean()
    print(avg_loss)
    tensorboard_logs = {"val_loss": avg_loss}
    self.log('avg_val_loss', avg_loss, on_step=False, on_epoch=True, prog_bar=True, logger=True)

  def configure_optimizers(self):
    "Prepare optimizer and schedule (linear warmup and decay)"

    model = self.model
    no_decay = ["bias", "LayerNorm.weight"]
    optimizer_grouped_parameters = [
        {
            "params": [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
            "weight_decay": self.hparams.weight_decay,
        },
        {
            "params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
            "weight_decay": 0.0,
        },
    ]
    optimizer = AdamW(optimizer_grouped_parameters, lr=self.hparams.learning_rate, eps=self.hparams.adam_epsilon)
    self.opt = optimizer
    return [optimizer]
  
  def optimizer_step(self,
                     epoch=None, 
                     batch_idx=None, 
                     optimizer=None, 
                     optimizer_idx=None, 
                     optimizer_closure=None, 
                     on_tpu=None, 
                     using_native_amp=None, 
                     using_lbfgs=None
                     ):

    optimizer.step(closure=optimizer_closure)
    optimizer.zero_grad()
    self.lr_scheduler.step()

  def train_dataloader(self):
    train_dataset = get_dataset(tokenizer=self.tokenizer, type_path="train", args=self.hparams)
    dataloader = DataLoader(train_dataset, batch_size=self.hparams.train_batch_size, drop_last=True, shuffle=True, num_workers=4)
    t_total = (
        (len(dataloader.dataset) // (self.hparams.train_batch_size * max(1, self.hparams.n_gpu)))
        // self.hparams.gradient_accumulation_steps
        * float(self.hparams.num_train_epochs)
    )
    scheduler = get_linear_schedule_with_warmup(
        self.opt, num_warmup_steps=self.hparams.warmup_steps, num_training_steps=t_total
    )
    self.lr_scheduler = scheduler
    return dataloader

  def val_dataloader(self):
    val_dataset = get_dataset(tokenizer=self.tokenizer, type_path="val", args=self.hparams)
    return DataLoader(val_dataset, batch_size=self.hparams.eval_batch_size, num_workers=4)

# %%
def write_weights(checkpoint_dir='/Users/akshatgoel/Desktop/checkpoints/', 
                  checkpoint_name = 'exp_9_rc_noise.ckpt', 
                  state_name = 'exp_9_rc_noise.pt'):
    '''
    ------------
    Input: 
    Output: 
    ------------
    '''
    # Set parameters
    checkpoint_path = os.path.join(checkpoint_dir, checkpoint_name)
    filepath = os.path.join(checkpoint_dir, state_name)

    model = T5FineTuner.load_from_checkpoint(checkpoint_path)
    torch.save(model.state_dict(), filepath)

# %%
checkpoint_dir='/Users/akshatgoel/Desktop/checkpoints/'

files = [f for f in os.listdir(checkpoint_dir) if f.endswith('ckpt')]

for i, checkpoint_name in enumerate(files):
    state_name = str(i) + '.pth'
    write_weights(checkpoint_dir, checkpoint_name, state_name)

# %%
files
# Out:
# ['exp_11_rc_ef_low_reg.ckpt',
#  'exp_9_rc_noise.ckpt',
#  'exp_10_rc_noise_ef.ckpt',
#  'exp_12_rc_low_reg.ckpt']
