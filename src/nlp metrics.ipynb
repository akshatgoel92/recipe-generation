# %%
import numpy as np 
import pandas as pd
import pickle as pkl

# %%
from rouge import rouge_n_sentence_level

summary_sentence = 'the capital of China is Beijing'.split()
reference_sentence = 'Beijing  the capital of China'.split()

# Calculate ROUGE-2.
recall, precision, rouge = rouge_n_sentence_level(summary_sentence, reference_sentence, 2)
print('ROUGE-2-R', recall)
print('ROUGE-2-P', precision)
print('ROUGE-2-F', rouge)
# Out:
# ROUGE-2-R 0.75
# ROUGE-2-P 0.6
# ROUGE-2-F 0.6666666666666665

# %%
x = pkl.load( open( "/Users/sarthak/Downloads/results/experiment_10_beam_outputs.pkl", "rb" ) )
print(x)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
type(x)
# Out:
# list

# %%
x = pkl.load( open( "/Users/sarthak/Downloads/results/experiment_11_beam_outputs.pkl", "rb" ) )

# %%
x = pkl.load( open( "/Users/sarthak/Downloads/results/experiment_12_beam_outputs.pkl", "rb" ) )
def avg_rouge(list1,list2):
    rouge_sum = 0
    for i in range(len(list1)):
        _,_,rouge = rouge_n_sentence_level(list1[i],list2[i], 2)
        rouge_sum +=rouge
    rouge_avg = rouge_sum/len(list1)
    return rouge_avg
rouge_avg = avg_rouge(x[2],x[3])
rouge_avg
# Out:
# 0.5814123538798982

# %%
import nltk
def get_avg_bleu(list1,list2):
    sumbleu = 0
    for i in range(len(list1)):
        hypothesis = list1[i].split(' ')
        reference = list2[i].split(' ')
        #the maximum is bigram, so assign the weight into 2 half.
        BLEUscore = nltk.translate.bleu_score.sentence_bleu([reference], hypothesis, weights = (0.5, 0.5))
        sumbleu+=BLEUscore
    avgbleu = sumbleu/len(list1)
    return avgbleu
x = pkl.load( open( "/Users/sarthak/Downloads/results/experiment_12_beam_outputs.pkl", "rb" ) )
bleu_avg = get_avg_bleu(x[3],x[2])
bleu_avg
# Out:
# /Users/sarthak/anaconda3/envs/voice_verf/lib/python3.8/site-packages/nltk/translate/bleu_score.py:516: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 0.20470226153411067

# %%
x[1]
# Out:
# [['ham slices',
#   'cornbread stuffing mix',
#   'cream of celery soup',
#   'cream of mushroom soup',
#   'sliced mushrooms',
#   'corn',
#   'onion',
#   'celery',
#   'cheese'],
#  ['unsalted butter', 'cheesecloth'],
#  ['nonfat dry milk powder',
#   'granulated sugar',
#   'baking cocoa',
#   'miniature marshmallows'],
#  ['baby greens',
#   'arugula',
#   'grape tomatoes',
#   'pine nuts',
#   'extra virgin olive oil',
#   'balsamic vinegar',
#   'parmesan cheese',
#   'salt and pepper'],
#  ['uncooked rice',
#   'wesson oil',
#   'onion',
#   'green pepper',
#   'celery',
#   'canned tomatoes',
#   'cubed ham'],
#  ['new potatoes',
#   'vegetable oil',
#   'coarse sea salt',
#   'sour cream',
#   'blue cheese',
#   'fresh chives'],
#  ['olive oil',
#   'butter',
#   'onions',
#   'garlic',
#   'fresh spinach',
#   'tomato sauce',
#   'water',
#   'fresh dill',
#   'salt and pepper',
#   'short-grain white rice',
#   'fresh lemon juice',
#   'feta cheese',
#   'hard-boiled egg'],
#  ['ground round',
#   'swiss cheese',
#   'fresh mushrooms',
#   'cheddar cheese',
#   'hamburger buns',
#   'salt and pepper',
#   'lettuce',
#   'tomatoes',
#   'onion'],
#  ['dutch-processed cocoa powder', 'sugar', 'dark chocolate', 'milk'],
#  ['lettuce',
#   'red onion',
#   'cheddar cheese',
#   'vegetarian baked beans',
#   'corn chips',
#   'tomatoes',
#   'vegetable oil',
#   'red wine vinegar',
#   'sugar',
#   'ketchup',
#   'onion powder'],
#  ['hard-boiled eggs',
#   'pickled jalapeno peppers',
#   'green onion',
#   'cilantro',
#   'ground cumin',
#   'mayonnaise',
#   'yellow mustard',
#   'lemon juice',
#   'salt and black pepper',
#   'bread'],
#  ['olive oil',
#   'onion',
#   'garlic cloves',
#   'mushroom',
#   'red bell pepper',
#   'eggplant',
#   'tomato sauce',
#   'chicken broth',
#   'dried thyme leaves',
#   'brown rice'],
#  ['cream cheese', 'milk', 'garlic powder', 'lemon juice', 'fresh chives'],
#  ['olive oil',
#   'ground turkey',
#   'garlic',
#   'onion',
#   'paprika',
#   'thyme',
#   'nonfat beef broth',
#   'medium egg noodles',
#   'fat free sour cream',
#   'flour',
#   'broccoli florets'],
#  ['water',
#   'carrots',
#   'onion',
#   'butter',
#   'sugar',
#   'chicken bouillon granule',
#   'cornstarch',
#   'cold water'],
#  ['raspberry vodka', 'kahlua', 'half-and-half'],
#  ['vegetable oil',
#   'red onion',
#   'garlic clove',
#   'chili powder',
#   'ground cumin',
#   'dried oregano',
#   'long grain white rice',
#   'chicken broth',
#   'diced tomatoes',
#   'green chilies',
#   'frozen corn',
#   'tabasco sauce',
#   'cilantro',
#   'scallion'],
#  ['flour', 'parmesan cheese', 'garlic salt', 'onion salt', 'basil'],
#  ['shortening',
#   'cornmeal',
#   'flour',
#   'baking powder',
#   'baking soda',
#   'salt',
#   'eggs',
#   'buttermilk'],
#  ['lean ground beef',
#   'taco seasoning mix',
#   'water',
#   'kidney beans',
#   'corn mixed with chopped peppers',
#   'biscuit mix',
#   'milk',
#   'cheddar cheese'],
#  ['chicken tenders',
#   'california-blend frozen vegetables',
#   'cream of chicken soup',
#   'sour cream',
#   'ranch dressing mix',
#   'mushrooms',
#   'diced green chilies',
#   'bacon'],
#  ['cranberries',
#   'sugar',
#   'granny smith apples',
#   'fresh ginger',
#   'water',
#   'cider vinegar',
#   'orange zest',
#   'cinnamon stick'],
#  ['chicken breasts',
#   'bacon',
#   'olive oil',
#   'yellow onion',
#   'garlic cloves',
#   'mushrooms',
#   'white rice',
#   'butter',
#   'cream of chicken soup',
#   'chicken broth',
#   'salt and pepper',
#   'sage',
#   'marjoram'],
#  ['olive oil',
#   'long grain rice',
#   'vegetable stock',
#   'water',
#   'pepper',
#   'black beans',
#   'tomatoes',
#   'unsalted butter',
#   'of fresh mint'],
#  ['pork chops', 'oil', 'onions', 'rice', 'vegetable juice'],
#  ['mango',
#   'peaches',
#   'jalapeno pepper',
#   'vidalia onion',
#   'red pepper',
#   'scallions',
#   'limes, juice of'],
#  ['milk',
#   'cornflour',
#   'flour',
#   'sugar',
#   'butter',
#   'apples',
#   'raisins',
#   'dried fig',
#   'pine nuts',
#   'grappa',
#   'rock salt',
#   'egg'],
#  ['red beans',
#   'white pepper',
#   'butter',
#   'paprika',
#   'cayenne',
#   'garlic powder',
#   'converted rice'],
#  ['fresh okra',
#   'all-purpose flour',
#   'cornmeal',
#   'egg',
#   'salt',
#   'pepper',
#   'lard'],
#  ['pears in heavy syrup',
#   'cream cheese',
#   'apricot preserves',
#   'butter',
#   'yellow cake mix',
#   'pear syrup',
#   'oil',
#   'egg',
#   'ground ginger'],
#  ['beef flank steak',
#   'salt',
#   'saltpeter',
#   'allspice',
#   'pepper',
#   'clove',
#   'onion',
#   'water',
#   'brown sugar'],
#  ['carrots',
#   'water',
#   'brown sugar',
#   'butter',
#   'toasted sesame seeds',
#   'fresh lemon juice',
#   'salt'],
#  ['vegetable oil',
#   'white rice',
#   'eggs',
#   'green onions',
#   'garlic cloves',
#   'soy sauce',
#   'salt',
#   'ground pepper',
#   'peas',
#   'carrot',
#   'corn kernel'],
#  ['baking potatoes',
#   'vidalia onion',
#   'bacon',
#   'olive oil',
#   'salt',
#   'pepper',
#   'garlic powder',
#   'aluminum foil'],
#  ['baking mix',
#   'milk',
#   'sugar',
#   'vegetable oil',
#   'egg substitute',
#   'blueberries'],
#  ['vegetable oil',
#   'onion',
#   'garlic cloves',
#   'red bell pepper',
#   'green bell pepper',
#   'vegetarian baked beans',
#   'butter beans',
#   'red beans',
#   'ketchup',
#   'light brown sugar',
#   'cider vinegar',
#   'mustard',
#   'hot dogs'],
#  ['quick-cooking oats',
#   'butter',
#   'all-purpose flour',
#   'brown sugar',
#   'salt',
#   'baking soda',
#   'dates',
#   'white sugar',
#   'water'],
#  ['lean ground beef',
#   'cumin',
#   'dried oregano',
#   'thick & chunky salsa',
#   'raisins',
#   'cream cheese spread',
#   'nonfat sour cream',
#   'crushed pineapple',
#   'green onion',
#   'pimiento'],
#  ['light brown sugar',
#   'white sugar',
#   'water',
#   'light corn syrup',
#   'salt',
#   'maple extract'],
#  ['limes',
#   'garlic cloves',
#   'black pepper',
#   'olive oil',
#   'fresh cilantro',
#   'cherry tomatoes',
#   'white button mushrooms',
#   'shrimp'],
#  ['bread',
#   'bacon',
#   'sausage',
#   'eggs',
#   'milk',
#   'cheddar cheese',
#   'mozzarella cheese',
#   'cream of mushroom soup',
#   'sour cream'],
#  ['butter', 'light brown sugar', 'milk', 'powdered sugar'],
#  ['chicken broth',
#   'tomatoes',
#   'garbanzo beans',
#   'artichoke hearts',
#   'garlic',
#   'dried basil',
#   'dried oregano',
#   'salt and pepper'],
#  ['fresh strawberries',
#   'prepared chocolate pudding',
#   'prepared vanilla pudding',
#   'whipped cream'],
#  ['brewed green tea', 'frozen mixed berries', 'banana', 'honey'],
#  ['self rising flour', 'sour cream', 'butter'],
#  ['hazelnuts', 'water'],
#  ['granola cereal',
#   'milk',
#   'butter',
#   'eggs',
#   'whole wheat flour',
#   'baking powder',
#   'baking soda',
#   'salt',
#   'shortening'],
#  ['unsalted butter',
#   'peanut butter',
#   'cream cheese',
#   'splenda granular',
#   'vanilla protein powder'],
#  ['mushrooms',
#   'italian sausage',
#   'cream cheese',
#   'sharp cheddar cheese',
#   'onion'],
#  ['silver beet', 'onion', 'garlic', 'bacon', 'red capsicum', 'curry powder'],
#  ['onion powder',
#   'celery salt',
#   'dried parsley flakes',
#   'garlic powder',
#   'salt',
#   'ground savory',
#   'dried marjoram',
#   'dried thyme',
#   'pepper',
#   'turmeric',
#   'ground sage'],
#  ['graham crackers', 'cream cheese', 'nutella'],
#  ['chuck steaks',
#   'onions',
#   'oil',
#   'butter',
#   'plain flour',
#   'beef stock',
#   'garlic',
#   'cumin',
#   'marjoram',
#   'wine vinegar',
#   'salt & freshly ground black pepper'],
#  ['linguine',
#   'boneless chicken breasts',
#   'cajun seasoning',
#   'butter',
#   'green onions',
#   'heavy cream',
#   'sun-dried tomatoes',
#   'dried basil',
#   'garlic powder',
#   'pepper',
#   'parmesan cheese'],
#  ['bibb lettuce',
#   'watercress',
#   'onion',
#   'english cucumber',
#   'salad oil',
#   'tarragon vinegar',
#   'worcestershire sauce',
#   'salt',
#   'sugar',
#   'coarse black pepper'],
#  ['butter',
#   'brown sugar',
#   'molasses',
#   'egg',
#   'flour',
#   'baking powder',
#   'baking soda',
#   'salt',
#   'cinnamon',
#   'ginger',
#   'buttermilk',
#   "confectioners' sugar",
#   'lemon, juice and zest of'],
#  ['ground round',
#   'chili hot beans',
#   'southwestern-flavored cornbread stuffing mix',
#   'fresh lime juice',
#   'pepper',
#   'jalapeno pepper cheese',
#   'green onion',
#   'lime wedge'],
#  ['vanilla ice cream', 'vodka', 'kahlua', 'bittersweet chocolate'],
#  ['cream-style corn',
#   'eggs',
#   'sugar',
#   'cornstarch',
#   'vanilla extract',
#   'unsalted butter',
#   'evaporated milk'],
#  ['sharp cheddar cheese',
#   'onion',
#   'almonds',
#   'bacon',
#   'mayonnaise',
#   'worcestershire sauce',
#   'sandwich bread'],
#  ['cucumber',
#   'garlic cloves',
#   'of fresh mint',
#   'fresh parsley',
#   'lime, juice of',
#   'dried oregano',
#   'salt and pepper',
#   'rice vinegar',
#   'olive oil',
#   'roma tomato',
#   'pita bread',
#   'garlic salt'],
#  ['salmon fillets',
#   'hoisin sauce',
#   'reduced-fat mayonnaise',
#   'fresh parsley',
#   'green onion',
#   'fresh ginger',
#   'minced garlic cloves',
#   'salt',
#   'black pepper'],
#  ['chicken',
#   'coriander seed',
#   'cayenne pepper',
#   'cumin',
#   'black pepper',
#   'salt',
#   'onions',
#   'garlic',
#   'bay leaves',
#   'fresh figs',
#   'mavrothaphne',
#   'lemon, juice and zest of',
#   'flat leaf parsley'],
#  ['tea bags',
#   'mint',
#   'lemons, zest of',
#   'boiling water',
#   'lemons, juice of',
#   'sugar',
#   'cold water'],
#  ['garlic powder', 'black pepper', 'parsley flakes'],
#  ['butter',
#   'red bell peppers',
#   'salt',
#   'fusilli',
#   'fontina',
#   'mozzarella cheese',
#   'parmesan cheese',
#   'fresh ground pepper'],
#  ['pork loin roast',
#   'salt',
#   'ground black pepper',
#   'cooking oil',
#   'apples',
#   'apple juice',
#   'brown sugar',
#   'ground ginger'],
#  ['lean ground beef',
#   'onion',
#   'celery',
#   'garlic',
#   'pepper',
#   'fresh mushrooms',
#   'beef bouillon powder',
#   'boiling water',
#   'soy sauce',
#   'long grain white rice'],
#  ['chicken breasts',
#   'italian seasoned breadcrumbs',
#   'fresh mushrooms',
#   'low-fat cream of mushroom soup',
#   'cream of chicken soup',
#   'olive oil',
#   'salt',
#   'pepper',
#   'cheese',
#   'toothpick',
#   'egg noodles'],
#  ['rice krispies',
#   'peanut butter',
#   'honey',
#   'butterscotch chips',
#   'semi-sweet chocolate chips'],
#  ['garlic', 'dried rosemary', 'salt', 'black pepper', 'lamb rib chops'],
#  ['hot water',
#   'instant coffee granules',
#   'french vanilla flavored coffee creamer',
#   'chocolate syrup',
#   'whipped cream'],
#  ['fresh blueberries',
#   'lemon flavor instant pudding and pie filling',
#   'lemon yogurt',
#   'angel food cake',
#   'frozen whipped topping',
#   'lemon slice'],
#  ['butter',
#   'tomato sauce',
#   'salt',
#   'sugar',
#   'white pepper',
#   'dried parsley',
#   'whipping cream',
#   'water',
#   'garlic powder',
#   'ginger powder',
#   'red chili peppers',
#   'ginger',
#   'fresh cilantro',
#   'chicken breasts marinated in tandoori paste'],
#  ['sauerkraut',
#   'onion',
#   'potatoes',
#   'carrot',
#   'green bell peppers',
#   'minced garlic cloves',
#   'low-fat turkey kielbasa',
#   'tart apple',
#   'crushed pineapple',
#   'chicken broth',
#   'white wine',
#   'brown sugar',
#   'pepper',
#   'caraway seed',
#   'salt'],
#  ['manioc starch',
#   'sunflower oil',
#   'low-fat milk',
#   'eggs',
#   'parmesan cheese',
#   'mild cheddar cheese'],
#  ['orange roughy',
#   'italian stewed tomatoes',
#   'dry white wine',
#   'salt & pepper',
#   'yellow onion',
#   'extra virgin olive oil',
#   'dried oregano',
#   'couscous'],
#  ['ground beef',
#   'onion',
#   'garlic clove',
#   'celery',
#   'green pepper',
#   'macaroni',
#   'tomato sauce',
#   'water',
#   'parsley',
#   'salt',
#   'pepper',
#   'worcestershire sauce',
#   'american cheese'],
#  ['cooked basmati rice',
#   'minced chicken',
#   'fresh tomato',
#   'mushrooms',
#   'egg',
#   'jalapeno peppers',
#   'fine breadcrumbs',
#   'green bell peppers',
#   'tomato sauce'],
#  ['ground beef',
#   'horseradish',
#   'heinz chili sauce',
#   'onions',
#   'tomato juice',
#   'salt',
#   'black pepper',
#   'sugar'],
#  ['cherries',
#   'cornstarch',
#   'sugar',
#   'lemon juice',
#   'lemon zest',
#   'almond extract',
#   'slivered almonds',
#   'whipped cream',
#   'ricotta cheese',
#   'cheese',
#   'plain yogurt'],
#  ['ground beef',
#   'onion',
#   'green bell pepper',
#   'garlic cloves',
#   'tomatoes',
#   'whole kernel corn',
#   'tomato sauce',
#   'elbow macaroni',
#   'parsley',
#   'salt and pepper'],
#  ['lime jell-o gelatin',
#   'boiling water',
#   'cream cheese',
#   'fresca soda',
#   'nuts'],
#  ['cajun seasoning', 'olive oil', 'large shrimp'],
#  ['eggs',
#   'zucchini',
#   'progresso plain bread crumbs',
#   'onion',
#   'salt',
#   'dried oregano leaves',
#   'pepper',
#   'lean ground beef',
#   'brown sugar',
#   'ketchup',
#   'yellow mustard'],
#  ['eggplants',
#   'penne pasta',
#   'olive oil',
#   'balsamic vinegar',
#   'garlic cloves',
#   'mint leaf',
#   'salt',
#   'white pepper',
#   'feta cheese',
#   'unsalted dry-roasted cashews'],
#  ['frozen spinach',
#   'blue crab meat',
#   'artichoke hearts',
#   'cream cheese',
#   'garlic powder',
#   'parmigiano',
#   'seasoned bread crumbs',
#   'alfredo sauce'],
#  ['cereal bars', 'natural-style peanut butter'],
#  ['large shrimp',
#   'unbleached white flour',
#   'cayenne pepper',
#   'chili powder',
#   'cumin',
#   'pepper',
#   'salt',
#   'corn oil',
#   'tabasco sauce'],
#  ['lime juice', 'olive oil', 'kelp', 'water', 'sesame seeds'],
#  ['garlic',
#   'onion',
#   'tomatoes',
#   'tomato paste',
#   'water',
#   'sugar',
#   'salt and pepper',
#   'olive oil',
#   'ground beef',
#   'seasoned bread crumbs',
#   'milk',
#   'egg',
#   'parmesan cheese',
#   'onion powder',
#   'dried basil',
#   'pepper',
#   'parsley flakes'],
#  ['oreo cookies',
#   'butter',
#   'cream cheese',
#   'powdered sugar',
#   'whipped topping',
#   'instant chocolate pudding mix'],
#  ['tomatoes',
#   'celery',
#   'carrot',
#   'onion',
#   'fresh basil',
#   'fresh rosemary',
#   'salt',
#   'cinnamon',
#   'whole cloves',
#   'peppercorns',
#   'garlic'],
#  ['pork spareribs', 'salt', 'pepper', 'barbecue sauce', 'onion'],
#  ['vanilla ice cream', 'vanilla vodka', 'frangelico', 'amaretto', 'pecans'],
#  ['kalamata olives',
#   'zucchini',
#   'sweet red pepper',
#   'onion',
#   'olive oil',
#   'eggs',
#   'feta cheese',
#   'fresh basil',
#   'salt',
#   'pepper',
#   'parmesan cheese'],
#  ['olive oil',
#   'garlic',
#   'spinach leaves',
#   'salt',
#   'fresh ground black pepper',
#   'parmesan cheese',
#   'red pepper flakes'],
#  ['italian dressing',
#   'soy sauce',
#   'brown sugar',
#   'ground ginger',
#   'flank steak'],
#  ['semisweet chocolate',
#   'sugar',
#   'salt',
#   'water',
#   'half-and-half',
#   'vanilla',
#   'hot coffee',
#   'ground nutmeg'],
#  ['chorizo sausage', 'onion', 'chickpeas', 'paprika', 'salt', 'pepper'],
#  ['unsalted butter',
#   'fresh raspberries',
#   'ground cinnamon',
#   'caster sugar',
#   'self-raising flour',
#   'free-range eggs',
#   'double cream'],
#  ['cod fish fillets', 'sage', 'salt', 'pepper', 'swiss cheese', 'sour cream'],
#  ['tomato juice',
#   'diced tomatoes',
#   'red kidney beans',
#   'beans',
#   'onion',
#   'garlic cloves',
#   'ground beef',
#   'chili powder',
#   'salt and pepper'],
#  ['malibu rum', 'midori melon liqueur', 'banana liqueur', 'pineapple juice'],
#  ['light soy sauce',
#   'olive oil',
#   'garlic',
#   'salt and pepper',
#   'portabella mushroom caps',
#   'hamburger buns',
#   'provolone cheese',
#   'lettuce leaves',
#   'roasted red pepper',
#   'tomatoes',
#   'mayonnaise',
#   'dijon-style mustard'],
#  ['garlic cloves',
#   'fresh basil leaves',
#   'fresh mint leaves',
#   'vegetable oil',
#   'cooked rice',
#   'instant chicken bouillon granules',
#   'light soy sauce',
#   'bonito flakes',
#   'fried onions',
#   'pepper'],
#  ['low-fat cream cheese',
#   'eggs',
#   'granulated sugar',
#   'sweet corn',
#   'cream-style corn',
#   'cornbread mix',
#   '% low-fat milk',
#   'unsalted butter',
#   'salt',
#   'ground nutmeg'],
#  ['campbell southwest-style pepper jack soup',
#   '% low-fat milk',
#   'pinto beans with jalapeno peppers',
#   'cumin',
#   'chili powder',
#   'onion powder',
#   'garlic powder',
#   'salt and pepper',
#   'elbow macaroni',
#   'cooked ground beef',
#   'cheese',
#   'onion',
#   'tomatoes',
#   'lettuce'],
#  ['boneless skinless chicken breasts',
#   'butter',
#   'fresh garlic',
#   'onion',
#   'tomatoes',
#   'basil',
#   'spaghettini',
#   'dry white wine',
#   'chicken broth',
#   'half-and-half cream',
#   'salt and pepper',
#   'fresh parsley',
#   'parmesan cheese'],
#  ['egg white', 'granulated sugar', 'corn syrup', 'water'],
#  ['dried mango',
#   'golden raisins',
#   'red onion',
#   'black tea',
#   'red pepper flakes',
#   'fresh ginger',
#   'red wine vinegar',
#   'corn syrup',
#   'garlic cloves',
#   'salt',
#   'mustard powder',
#   'ground allspice'],
#  ['catsup',
#   'grape jelly',
#   'lemon juice',
#   'prepared mustard',
#   'pineapple chunks',
#   'cocktail franks'],
#  ['butter',
#   'diced onions',
#   'eggs',
#   'milk',
#   'cheese',
#   'fresh parsley',
#   'salt and pepper'],
#  ['green apple vodka', 'triple sec', 'grenadine', 'cranberry juice'],
#  ['spam',
#   'pineapple',
#   'jalapeno pepper',
#   'onion',
#   'raw rice',
#   'chicken stock',
#   'pineapple juice',
#   'olive oil',
#   'butter'],
#  ['apples', 'brown sugar', 'flour', 'oats', 'cinnamon', 'nutmeg', 'butter'],
#  ['flour',
#   'sugar',
#   'baking powder',
#   'baking soda',
#   'ground cinnamon',
#   'ground ginger',
#   'salt',
#   'ground nutmeg',
#   'eggs',
#   'vegetable oil',
#   'pumpkin',
#   'crushed pineapple',
#   'pecans'],
#  ['dry buttermilk',
#   'all-purpose flour',
#   'baking powder',
#   'salt',
#   'baking soda',
#   'sugar',
#   'shortening',
#   'water'],
#  ['lean ground turkey',
#   'onion',
#   'garlic',
#   'jalapeno pepper',
#   'green bell pepper',
#   'chili powder',
#   'pico de gallo',
#   'salsa',
#   'cheddar cheese',
#   'seasoning salt',
#   'black pepper',
#   'tortilla chips',
#   'sour cream',
#   'green onions',
#   'lettuce'],
#  ['onion',
#   'turmeric',
#   'ground coriander',
#   'unsalted butter',
#   'long-grain rice',
#   'chicken broth',
#   'pine nuts',
#   'golden raisins'],
#  ['ham', 'cheddar cheese', 'bread dough'],
#  ['flour',
#   'yellow cornmeal',
#   'sugar',
#   'baking powder',
#   'salt',
#   'egg',
#   'milk',
#   'butter'],
#  ['coffee', 'chocolate ice cream', 'chocolate syrup', 'ice', 'whipped cream'],
#  ['mayonnaise',
#   'ketchup',
#   'sugar',
#   'white vinegar',
#   'dry mustard',
#   'horseradish'],
#  ['apple cider',
#   'brown sugar',
#   'butter',
#   'lemon juice',
#   'ground cloves',
#   'cornstarch',
#   'water'],
#  ['canned pumpkin',
#   'apple butter',
#   'dark brown sugar',
#   'ground cinnamon',
#   'ground ginger',
#   'ground nutmeg',
#   'salt',
#   'eggs',
#   'evaporated milk',
#   'deep dish pie shells',
#   'butter',
#   'flour',
#   'pecans'],
#  ['black-eyed peas',
#   'diced pimentos',
#   'red onion',
#   'red wine vinegar',
#   'sugar',
#   'canola oil',
#   'ground red pepper',
#   'salt'],
#  ['bacon',
#   'onion',
#   'celery',
#   'garlic',
#   'flour',
#   'sherry wine',
#   'chicken broth',
#   'frozen corn kernels',
#   'red potatoes',
#   'whole milk',
#   'chipotle chile in adobo',
#   'fresh thyme',
#   'medium shrimp',
#   'heavy cream',
#   'salt'],
#  ['fresh broccoli florets',
#   'water',
#   'cottage cheese',
#   'eggs',
#   'butter',
#   'all-purpose flour',
#   'whole kernel corn',
#   'cheddar cheese',
#   'green onion',
#   'salt',
#   'black pepper',
#   'cayenne pepper',
#   'bacon'],
#  ['turnip', 'chili powder', 'sea salt', 'oil'],
#  ['butter',
#   'shallots',
#   'garlic',
#   'celery',
#   'kahlua',
#   'ketchup',
#   'low sodium soy sauce',
#   'whiskey',
#   'balsamic vinegar',
#   'cider vinegar',
#   'worcestershire sauce',
#   'dijon mustard',
#   'liquid smoke',
#   'brown sugar',
#   'kosher salt',
#   'fresh ground pepper'],
#  ['flour',
#   'parmesan cheese',
#   'paprika',
#   'potatoes',
#   'milk',
#   'butter',
#   'fat free sour cream',
#   'bacon',
#   'chives',
#   'garlic powder'],
#  ['banana',
#   'wafer cookies',
#   'sweetened condensed milk',
#   'cool whip',
#   'instant vanilla pudding'],
#  ['oats',
#   'flour',
#   'wholemeal rye flour',
#   'salt',
#   'baking powder',
#   'brown sugar',
#   'eggs',
#   'skim milk',
#   'vegetable oil',
#   'dried cranberries',
#   'chocolate chips'],
#  ['peach juice',
#   'apple juice',
#   'orange slices',
#   'candied ginger',
#   'ground cinnamon',
#   'ground nutmeg'],
#  ['fresh garlic cloves',
#   'salt',
#   'black pepper',
#   'butter',
#   'fresh parsley',
#   'dried thyme',
#   'lemon zest'],
#  ['boneless skinless chicken breasts',
#   'hoisin sauce',
#   'rice wine',
#   'low sodium soy sauce',
#   'ketchup',
#   'brown sugar',
#   'garlic'],
#  ['white cake mix',
#   'mandarin oranges in juice',
#   'eggs',
#   'cool whip',
#   'instant banana pudding mix',
#   'crushed pineapple'],
#  ['paprika', 'chili powder', 'oregano', 'salt'],
#  ['flour',
#   'milk',
#   'salt',
#   'eggs',
#   'blueberries',
#   'butter',
#   'lemon',
#   'powdered sugar'],
#  ['peanut butter',
#   'butter',
#   "confectioners' sugar",
#   'cocoa',
#   'vanilla extract'],
#  ['large curd cottage cheese',
#   'milk',
#   'sour cream',
#   'pepper',
#   'red pepper',
#   'salt',
#   'accent seasoning',
#   'garlic salt',
#   'celery salt',
#   'onion soup mix'],
#  ['refrigerated crescent dinner rolls', 'pesto sauce', 'fresh crabmeat'],
#  ['crabmeat',
#   'whole wheat tortillas',
#   'brie cheese',
#   'mixed baby greens',
#   'tomatoes',
#   'cooked bacon',
#   'mayonnaise',
#   'fresh dill'],
#  ['chicken liver',
#   'turkey bacon',
#   'shallot',
#   'port wine',
#   'eggs',
#   'allspice',
#   'salt',
#   'white pepper',
#   'milk'],
#  ['water', 'iced tea', 'fruit juice', 'fresh raspberry'],
#  ['rice wine vinegar',
#   'peanut butter',
#   'lime juice',
#   'soy sauce',
#   'honey',
#   'cilantro',
#   'ginger',
#   'garlic',
#   'hot pepper flakes'],
#  ['mixed dried fruit', 'black coffee', 'self-raising flour'],
#  ['peaches', 'brown sugar', 'white sugar', 'lemon, rind of', 'rum'],
#  ['water',
#   'cider vinegar',
#   'salt',
#   'mustard seeds',
#   'black peppercorns',
#   'zucchini',
#   'onion',
#   'garlic cloves',
#   'red bell pepper',
#   'fresh dill leaves'],
#  ['shortening',
#   'white sugar',
#   'brown sugar',
#   'egg',
#   'vanilla',
#   'baking soda',
#   'salt',
#   'dandelion flowers',
#   'all-purpose flour'],
#  ['cooked chicken breast',
#   'frozen chopped broccoli',
#   'avocado',
#   'rice',
#   'tomatoes',
#   'mozzarella cheese',
#   'egg',
#   'mayonnaise',
#   'dijon mustard',
#   'celery seed',
#   'pita pockets'],
#  ['eggs',
#   'sugar',
#   'butter',
#   'fresh lemon rind',
#   'orange rind',
#   'desiccated coconut',
#   'plain flour',
#   'lemon juice',
#   'orange juice',
#   'milk'],
#  ['powdered cocoa mix', 'unsweetened raspberry kool-aid'],
#  ['apple juice', 'red cinnamon candies'],
#  ['edamame',
#   'sea salt',
#   'chili powder',
#   'ground cumin',
#   'cayenne pepper',
#   'wasabi powder',
#   'ground ginger',
#   'curry powder',
#   'ground coriander',
#   'ground cinnamon'],
#  ['strawberries', 'kiwi fruits', 'mango', 'sparkling white wine'],
#  ['chicken breasts',
#   'butter chicken paste',
#   'butter',
#   'tomato puree',
#   'garlic',
#   'light cream',
#   'jasmine rice',
#   'coriander'],
#  ['apples',
#   'flour',
#   'eggs',
#   'crisco cooking oil',
#   'vanilla',
#   'baking soda',
#   'nuts',
#   'salt',
#   'sugar',
#   'cinnamon',
#   'cream cheese',
#   "confectioners' sugar"],
#  ['french baguettes',
#   'extra virgin olive oil',
#   'kalamata olive',
#   'red bell peppers',
#   'asiago cheese',
#   'fresh parsley',
#   'basil leaves'],
#  ['flour', 'baking powder', 'butter', 'sugar', 'ginger', 'milk', 'egg'],
#  ['beef brisket',
#   'liquid smoke',
#   'celery salt',
#   'pepper',
#   'salt',
#   'onion',
#   'dark beer',
#   'worcestershire sauce',
#   'cornstarch',
#   'cold water'],
#  ['sugar',
#   'flour',
#   'baking soda',
#   'cinnamon',
#   'salt',
#   'eggs',
#   'oil',
#   'butter',
#   'pecans',
#   'coconut',
#   'raisins',
#   'apple',
#   'carrots'],
#  ['egg', 'milk', 'nutmeg', 'sugar', 'bread', 'butter'],
#  ['red cabbage', 'apple cider vinegar', 'honey', 'olive oil', 'salt & pepper'],
#  ['chicken',
#   'celery',
#   'garlic',
#   'soy sauce',
#   'sesame seed oil',
#   'vinegar',
#   'salt'],
#  ['strawberry',
#   'apple juice concentrate',
#   'salt',
#   'cornstarch',
#   'neufchatel cheese',
#   'white grape juice concentrate',
#   'pie crust'],
#  ['button mushroom',
#   'eggs',
#   'milk',
#   'black pepper',
#   'italian seasoned breadcrumbs',
#   'butter'],
#  ['hard-boiled eggs',
#   'potato',
#   'eggs',
#   'garlic',
#   'salt',
#   'dijon mustard',
#   'fresh rosemary',
#   'saltine crackers',
#   'vegetable oil'],
#  ['honey',
#   'peanut butter',
#   'nonfat dry milk powder',
#   'fiber one cereal',
#   'puffed wheat cereal',
#   'cereal'],
#  ['unsweetened frozen peach slices',
#   'skim milk',
#   'nonfat yogurt',
#   'honey',
#   'cinnamon',
#   'nutmeg',
#   'ground ginger',
#   'vanilla extract'],
#  ['olive oil',
#   'fresh lime juice',
#   'garlic',
#   'ground cumin',
#   'oregano leaves',
#   'kosher salt',
#   'beef t-bone steaks',
#   'butter',
#   'onions',
#   'habanero',
#   'cooked macaroni',
#   'monterey jack cheese',
#   'chili paste',
#   'black pepper',
#   'green onions'],
#  ['potatoes',
#   'tomatoes',
#   'monterey jack cheese',
#   'eggs',
#   'milk',
#   'seasoning salt',
#   'pepper',
#   'parsley'],
#  ['ground meat substitute',
#   'minced garlic cloves',
#   'milk',
#   'parmesan cheese',
#   'egg',
#   'basil',
#   'oregano',
#   'parsley',
#   'caraway seed',
#   'fennel seed',
#   'breadcrumbs',
#   'pine nuts'],
#  ['beef round steak',
#   'all-purpose flour',
#   'dry mustard',
#   'salt',
#   'dried thyme leaves',
#   'black pepper',
#   'butter',
#   'vegetable oil',
#   'stewed tomatoes',
#   'onion',
#   'celery',
#   'carrots',
#   'brown sugar',
#   'sour cream'],
#  ['peanut butter',
#   'salt',
#   'water',
#   'eggs',
#   'butter',
#   'buttermilk',
#   'flour',
#   'baking soda',
#   'sugar',
#   'vanilla',
#   'powdered sugar'],
#  ['tequila', 'triple sec', 'fresh lime juice', 'pineapple juice'],
#  ['potatoes', 'onion', 'butter', 'lemon pepper'],
#  ['sugar', 'water', 'fresh cranberries', 'brandy'],
#  ['chicken tenderloins',
#   'olive oil',
#   'lemon juice',
#   'oregano',
#   'salt',
#   'black pepper'],
#  ['white fish fillets',
#   'dijon mustard',
#   'low sodium soy sauce',
#   'dry white wine',
#   'sesame seeds'],
#  ['ground turkey',
#   'onion',
#   'green pepper',
#   'garlic cloves',
#   'black beans',
#   'fresh tomatoes',
#   'frozen corn',
#   'chili powder',
#   'ground cumin',
#   'salsa',
#   'salt and pepper'],
#  ['cooking oil',
#   'onions',
#   'beef mince',
#   'canned tomatoes',
#   'tomato paste',
#   'oregano',
#   'thyme',
#   'basil',
#   'salt and pepper'],
#  ['refrigerated crescent dinner rolls',
#   'butter',
#   'sugar',
#   'cinnamon',
#   'raisins',
#   'powdered sugar',
#   'milk'],
#  ['flour',
#   'sugar',
#   'unsweetened cocoa',
#   'baking soda',
#   'baking powder',
#   'eggs',
#   'milk',
#   'vegetable oil',
#   'vanilla',
#   'boiling water'],
#  ['light karo syrup',
#   'white sugar',
#   'peanut butter',
#   'rice krispies',
#   'chocolate chips',
#   'butterscotch chips'],
#  ['butter',
#   'onion',
#   'cabbage',
#   'salt',
#   'pepper',
#   'wide egg noodles',
#   'sour cream'],
#  ['tilapia fillets',
#   'salt',
#   'ground black pepper',
#   'flour',
#   'instant potato flakes',
#   'parmesan cheese',
#   'parsley',
#   'garlic powder',
#   'eggs'],
#  ['prepared macaroni and cheese',
#   'chili',
#   'chipotle hot sauce',
#   'cheese',
#   'onions'],
#  ['fresh mushrooms',
#   'white bread',
#   'milk',
#   'garlic',
#   'flat-leaf italian parsley',
#   'eggs',
#   'ricotta cheese',
#   'salt and pepper',
#   'olive oil',
#   'romano cheese'],
#  ['hot water',
#   'granulated sugar',
#   'fresh lime juice',
#   'fresh lemon juice',
#   'yellow food coloring'],
#  ['warm water',
#   'yeast',
#   'flour',
#   'salt',
#   'olive oil',
#   'green peppers',
#   'pepperoni',
#   'mozzarella cheese',
#   'oregano',
#   'parmesan cheese'],
#  ['beef roast',
#   'olive oil',
#   'worcestershire sauce',
#   'dried basil',
#   'beef stock',
#   'garlic cloves',
#   'dry red wine',
#   'baby potatoes',
#   'carrots',
#   'onions',
#   'flour',
#   'sugar',
#   'salt and pepper'],
#  ['butter',
#   'low-fat cream cheese',
#   'garlic clove',
#   '% low-fat milk',
#   'fresh parmesan cheese',
#   'ground black pepper',
#   'nutmeg'],
#  ['butter',
#   'apples',
#   'brown sugar',
#   'cinnamon',
#   'flour',
#   'milk',
#   'eggs',
#   'salt'],
#  ['ground beef',
#   'garlic cloves',
#   'onion',
#   'green pepper',
#   'egg',
#   'italian seasoned breadcrumbs',
#   'tomato juice',
#   'salt and pepper',
#   'cooked white rice'],
#  ['ground lamb',
#   'egg whites',
#   'minced garlic clove',
#   'parsley',
#   'dried oregano',
#   'onion',
#   'rice',
#   'dried mint',
#   'vegetable oil',
#   'chicken stock',
#   'lemon juice',
#   'egg yolks',
#   'egg',
#   'salt and pepper'],
#  ['flour',
#   "confectioners' sugar",
#   'unsweetened cocoa',
#   'margarine',
#   'cream cheese',
#   'sweetened condensed milk',
#   'egg',
#   'vanilla extract',
#   'nuts'],
#  ['ground beef',
#   'ramen mushroom-flavor noodles',
#   'frozen mixed vegetables',
#   'water'],
#  ['blue curacao',
#   'triple sec',
#   'butterscotch schnapps',
#   'orange juice',
#   'ice'],
#  ['tuna in water',
#   'granny smith apple',
#   'orange bell peppers',
#   'red onion',
#   'jalapeno pepper',
#   'hard-boiled eggs',
#   'mayonnaise',
#   'limes, juice and zest of',
#   'garlic salt',
#   'lemon pepper',
#   'hot sauce'],
#  ['frozen limeade concentrate', 'sugar', 'cherry -up'],
#  ['rice',
#   'water',
#   'chicken bouillon',
#   'vinegar',
#   'butter',
#   'olive oil',
#   'red bell pepper',
#   'green bell peppers',
#   'zucchini',
#   'corn kernel',
#   'cilantro leaf'],
#  ['all-purpose flour',
#   'baking powder',
#   'butter',
#   'salt',
#   'garlic powder',
#   'black pepper',
#   'rosemary',
#   'olive oil',
#   'milk',
#   'cheddar cheese'],
#  ['water', 'sugar', 'fresh mint leaves', 'oranges', 'fresh lemon juice'],
#  ['vegetable oil cooking spray',
#   'flour',
#   'cornmeal',
#   'sugar',
#   'baking powder',
#   'salt',
#   'semi-sweet chocolate chips',
#   'whole milk',
#   'canola oil',
#   'eggs'],
#  ['sugar',
#   'hot water',
#   'buttermilk',
#   'fresh orange juice',
#   'fresh lemon juice',
#   'vanilla extract',
#   'ice cubes',
#   'gingersnaps',
#   'lemons, zest of',
#   'lemon slices'],
#  ['potatoes',
#   'whipping cream',
#   'butter',
#   'salt',
#   'pepper',
#   'onion',
#   'garlic clove',
#   'flour',
#   'beef broth',
#   'dijon mustard',
#   'dried thyme',
#   'fresh parsley',
#   'cooked pork'],
#  ['boneless skinless chicken breasts',
#   'catalina dressing',
#   'dry onion soup mix',
#   'apricot jam'],
#  ['strawberries',
#   'strawberry jell-o gelatin dessert',
#   'cornstarch',
#   'sugar',
#   'strawberry extract'],
#  ['german chocolate cake mix',
#   'egg',
#   'water',
#   'butter',
#   'snickers candy bars',
#   'cream cheese',
#   'eggs',
#   'powdered sugar'],
#  ['chicken',
#   'garlic oil',
#   'onion',
#   'fresh ginger',
#   'hearts of palm',
#   'artichoke heart',
#   'tomatoes',
#   'garlic',
#   'fresh dill',
#   'salt and pepper'],
#  ['butter',
#   'whole wheat flour',
#   'baking powder',
#   'dried cranberries',
#   'golden raisin',
#   'coconut',
#   'light brown sugar',
#   'pumpkin pie spice',
#   'carrot',
#   'eggs',
#   'milk'],
#  ['vegetable oil',
#   'pork loin',
#   'green onions',
#   'carrot',
#   'soy sauce',
#   'orange juice',
#   'salt',
#   'broccoli florets',
#   'lime zest',
#   'butter'],
#  ['frozen french fries', 'bacon', 'cheddar cheese', 'green onion'],
#  ["confectioners' sugar",
#   'butter',
#   'almond extract',
#   'egg',
#   'bisquick baking mix',
#   'decorator sugar'],
#  ['flour',
#   'baking soda',
#   'nutmeg',
#   'cinnamon',
#   'salt',
#   'ground cloves',
#   'mace',
#   'fresh ginger',
#   'butter',
#   'white sugar',
#   'brown sugar',
#   'egg',
#   'milk',
#   'molasses'],
#  ['broccoli florets',
#   'farfalle pasta',
#   'boneless chicken breasts',
#   'gorgonzola',
#   'white wine vinegar',
#   'extra virgin olive oil',
#   'fresh sage',
#   'salt and pepper'],
#  ['soy sauce',
#   'sugar',
#   'sesame oil',
#   'garlic clove',
#   'scallion',
#   'whole chicken breasts'],
#  ['garlic',
#   'philadelphia cream cheese',
#   'roasted red pepper',
#   'dry marsala wine',
#   'olive oil',
#   'salt',
#   'white pepper'],
#  ['refried beans',
#   'diced tomatoes',
#   'chicken broth',
#   'unsweetened coconut milk',
#   'green chilies',
#   'taco seasoning mix',
#   'sharp cheddar cheese',
#   'flour tortillas',
#   'tortilla',
#   'vegetable oil',
#   'fresh cilantro',
#   'green onions'],
#  ['ground beef',
#   'onions',
#   'green bell peppers',
#   'fresh garlic',
#   'butternut squash',
#   'acorn squash',
#   'potatoes',
#   'tomato sauce',
#   'worcestershire sauce',
#   'tomatoes',
#   'yellow squash',
#   'zucchini',
#   'salt and pepper',
#   'swiss cheese'],
#  ['egg',
#   'salt',
#   'vegetable oil',
#   'cider vinegar',
#   'seasoning',
#   'garlic',
#   'ground pepper',
#   'chicken parts'],
#  ['ground beef', 'velveeta cheese', 'milk', 'prepared mustard', 'ketchup'],
#  ['soda crackers', 'butter', 'brown sugar', 'chocolate chips', 'nuts'],
#  ['olive oil',
#   'celery',
#   'green pepper',
#   'garlic',
#   'onion',
#   'ground turkey',
#   'diced tomatoes',
#   'salt and pepper',
#   'rice',
#   'water'],
#  ['baby carrots', 'butter', 'brown sugar', 'salt'],
#  ['frangelico',
#   'butterscotch schnapps',
#   'orange curacao',
#   'cream',
#   'creme de banane',
#   'milk'],
#  ['chicken breasts',
#   'peanut oil',
#   'green cabbage',
#   'carrot',
#   'mushrooms',
#   'green onion',
#   'ginger',
#   'flour tortillas',
#   'hoisin sauce',
#   'soy sauce',
#   'water',
#   'sesame oil',
#   'garlic cloves',
#   'sugar'],
#  ['tomatoes',
#   'breadcrumbs',
#   'horseradish',
#   'lemon juice',
#   'salt',
#   'paprika',
#   'fresh parsley',
#   'parmesan cheese'],
#  ['milk',
#   'vinegar',
#   'eggs',
#   'flour',
#   'sugar',
#   'vanilla',
#   'salt',
#   'oil',
#   'fruit',
#   'whipped cream',
#   'nutella'],
#  ['sausage',
#   'corn',
#   'milk',
#   'egg',
#   'saltine crackers',
#   'tater tots',
#   'salt',
#   'pepper'],
#  ['extra virgin olive oil',
#   'lemon, juice of',
#   'fresh basil',
#   'sea salt',
#   'fresh black pepper',
#   'cherry tomatoes',
#   'yellow squash',
#   'fresh mozzarella cheese',
#   'bamboo skewer'],
#  ['syrup',
#   'ginger',
#   'water',
#   'pure maple syrup',
#   'carbonated water',
#   'lemon juice',
#   'lemon, rind of'],
#  ['onion',
#   'ground beef',
#   'long-grain rice',
#   'raw potatoes',
#   'carrots',
#   'celery',
#   'canned kidney beans',
#   'salt',
#   'pepper',
#   'chili powder',
#   'worcestershire sauce',
#   'tomato sauce',
#   'water'],
#  ['chicken thighs',
#   'lime',
#   'all-purpose flour',
#   'salt',
#   'paprika',
#   'vegetable oil',
#   'brown sugar',
#   'chicken broth',
#   'white wine',
#   'of fresh mint'],
#  ['sweet italian sausage links',
#   'red bell peppers',
#   'green bell peppers',
#   'olive oil',
#   'sweet onions',
#   'garlic',
#   'salt',
#   'ground black pepper',
#   'hoagie rolls'],
#  ['peach halves in syrup',
#   'peach nectar',
#   'frozen sliced strawberries in syrup',
#   'cantaloupe'],
#  ['jalapeno peppers',
#   'water',
#   'white vinegar',
#   'fresh lemon juice',
#   'green onions',
#   'fresh cilantro',
#   'salt'],
#  ['soy sauce',
#   'cornstarch',
#   'gingerroot',
#   'sesame oil',
#   'garlic cloves',
#   'pepper',
#   'top sirloin steak',
#   'garlic scapes',
#   'hot red pepper',
#   'vegetable oil',
#   'salt',
#   'beef stock'],
#  ['all-purpose flour', 'baking powder', 'salt', 'butter', 'milk', 'ice water'],
#  ['sugar',
#   'cornstarch',
#   'ground cinnamon',
#   'evaporated milk',
#   'semi-sweet chocolate chips',
#   'egg yolk',
#   'flaked coconut'],
#  ['vegetable oil',
#   'zucchini',
#   'onion',
#   'vegetable stock',
#   'tomatoes',
#   'fresh basil',
#   'garlic cloves',
#   'pepper',
#   'parmesan cheese'],
#  ['hot water',
#   'instant minced onion',
#   'beef baby food',
#   'lean ground beef',
#   'beef broth',
#   'hot dog buns'],
#  ['sesame seeds', 'limes, juice of', 'bananas', 'sugar', 'water'],
#  ['butter',
#   'flour',
#   'brown sugar',
#   'salt',
#   'honey',
#   'cream',
#   'vanilla',
#   'pecans'],
#  ['water', 'long grain rice', 'butter', 'salt and pepper', 'onion'],
#  ['evaporated milk',
#   'unsalted butter',
#   'eggs',
#   'lemon rind',
#   'vanilla extract',
#   'sugar',
#   'salt',
#   'ascorbic acid',
#   'bread flour',
#   'quick-rising yeast'],
#  ['sugar',
#   'butter',
#   'vanilla',
#   'eggs',
#   'all-purpose flour',
#   'baking powder',
#   'baking soda',
#   'salt',
#   'skor english toffee bits'],
#  ['peanut oil',
#   'onion',
#   'gingerroot',
#   'garlic',
#   'green chilies',
#   'turmeric',
#   'mushrooms',
#   'salt',
#   'cumin seed',
#   'lemon juice',
#   'fresh coriander leaves'],
#  ['eggs',
#   'evaporated milk',
#   'sugar',
#   'cinnamon',
#   'pure vanilla extract',
#   'butter',
#   'french bread',
#   'powdered sugar'],
#  ['pork tenderloin',
#   'salt',
#   'ground black pepper',
#   'garlic granules',
#   'plain flour',
#   'olive oil',
#   'dry white wine',
#   'fat-free low-sodium chicken broth',
#   'kalamata olive',
#   'capers',
#   'flat leaf parsley'],
#  ['millet',
#   'vegetable broth',
#   'cucumber',
#   'tomatoes',
#   'red bell pepper',
#   'feta cheese',
#   'olive oil',
#   'lemon, juice of',
#   'garlic clove',
#   'sea salt',
#   'mustard',
#   'pepper',
#   'oregano',
#   'basil',
#   'dried thyme'],
#  ['chuck roast',
#   'onion',
#   'water',
#   'celery',
#   'garlic cloves',
#   'catsup',
#   'brown sugar',
#   'cider vinegar',
#   'allspice',
#   'soy sauce',
#   'dry mustard',
#   'chili powder',
#   'hot sauce',
#   'worcestershire sauce',
#   'bay leaf',
#   'garlic salt',
#   'salt'],
#  ['unsalted butter',
#   'smooth peanut butter',
#   'sugar',
#   'eggs',
#   'vanilla extract',
#   'self-rising flour',
#   'peanut butter chips',
#   'heavy cream',
#   'heath candy bars',
#   'unsalted peanuts'],
#  ['country-style boneless pork ribs',
#   'barbecue sauce',
#   'red onion',
#   'green bell pepper',
#   'yellow bell pepper',
#   'garlic cloves',
#   'red pepper',
#   'salt and pepper'],
#  ['fudge brownie mix',
#   'water',
#   'vegetable oil',
#   'eggs',
#   'instant chocolate fudge pudding',
#   'caramel topping',
#   'frozen whipped topping',
#   'walnuts'],
#  ['strawberry', 'mashed bananas', 'water', 'lemon juice'],
#  ['coffee', 'salt', 'pepper'],
#  ['sauerkraut',
#   'cooking apple',
#   'onions',
#   'barley',
#   'pork loin',
#   'barbecue sauce'],
#  ['chili sauce',
#   'rice wine',
#   'rice wine vinegar',
#   'sesame oil',
#   'fresh ginger',
#   'fresh garlic',
#   'red pepper flakes'],
#  ['all-purpose flour',
#   'yellow cornmeal',
#   'baking powder',
#   'red bell peppers',
#   'salt',
#   'ground red pepper',
#   'whole kernel corn',
#   '% low-fat milk',
#   'egg substitute',
#   'vegetable oil',
#   'egg whites',
#   'cooking spray'],
#  ['american cheese', 'diced green chilies', 'heavy cream'],
#  ['flour tortillas',
#   'peanut butter',
#   'banana',
#   'peanuts',
#   'mini chocolate chip'],
#  ['chicken broth',
#   'poultry seasoning',
#   'onion powder',
#   'garlic powder',
#   'black pepper',
#   'salt',
#   'milk',
#   'flour'],
#  ['fat free cream cheese',
#   'sugar-free instant vanilla pudding mix',
#   'powdered milk',
#   'coffee',
#   'brandy extract',
#   'cool whip',
#   'chocolate wafer pie crust',
#   'unsweetened cocoa'],
#  ['penne pasta',
#   'italian sausage',
#   'baby spinach',
#   'diced tomatoes with basil oregano and garlic',
#   'mozzarella cheese',
#   'parmesan cheese'],
#  ['medium egg noodles',
#   'vegetable oil',
#   'onion',
#   'red chile',
#   'garlic cloves',
#   'fresh ginger',
#   'ground coriander',
#   'turmeric',
#   'lemongrass',
#   'coconut milk',
#   'vegetable stock',
#   'cabbage',
#   'green beans',
#   'mushrooms',
#   'unsalted peanuts'],
#  ['coleslaw mix',
#   'green onion',
#   'granny smith apples',
#   'sugar',
#   'salt',
#   'apple pie spice',
#   'cider vinegar',
#   'oil'],
#  ['% low-fat milk',
#   'vanilla ice cream',
#   'unsweetened pineapple chunks',
#   'ground cinnamon'],
#  ['bisquick', 'granola cereal', 'honey', 'egg', 'milk', 'raisins'],
#  ['heavy whipping cream',
#   'oreo cookies',
#   'egg yolks',
#   'sweetened condensed milk',
#   'vanilla extract'],
#  ['red sweet peppers',
#   'green tomatoes',
#   'onions',
#   'cabbage',
#   'sweet green peppers',
#   'pickling salt',
#   'sugar',
#   'cider vinegar',
#   'water',
#   'mustard seeds',
#   'ground turmeric',
#   'celery seeds'],
#  ['plain low-fat yogurt',
#   'fresh tomatoes',
#   'salt',
#   'extra virgin olive oil',
#   'fresh lemon juice',
#   'garlic clove',
#   'scallions',
#   'ground cumin',
#   'fresh oregano',
#   'pepper',
#   'feta cheese'],
#  ['pineapple chunks',
#   'cream of coconut',
#   'gingerroot',
#   'tequila',
#   'rum',
#   'creme de almond',
#   'orange juice concentrate',
#   'ice cubes',
#   'cherries'],
#  ['whipped cream cheese',
#   'sour cream',
#   'garlic cloves',
#   'dried thyme',
#   'dried oregano',
#   'salt',
#   'pepper',
#   'fresh parsley'],
#  ['pork shoulder',
#   'hominy',
#   'ancho chilies',
#   'guajillo chilies',
#   'garlic',
#   'black pepper',
#   'salt',
#   'cabbage',
#   'radish',
#   'white onion',
#   'fresh cilantro',
#   'lime',
#   'red chili pepper flakes',
#   'oregano'],
#  ['midori melon liqueur',
#   'strawberry liqueur',
#   'lemon juice',
#   'strawberries',
#   'lemonade'],
#  ['rolled oats',
#   'water',
#   'raisins',
#   'maple syrup',
#   'soymilk',
#   'ground cinnamon',
#   'ground ginger'],
#  ['ground beef',
#   'lettuce',
#   'tomatoes',
#   'green onions',
#   'kidney beans',
#   'cheddar cheese',
#   'taco chips',
#   'taco seasoning',
#   'coleslaw dressing'],
#  ['beef brisket',
#   'coca-cola',
#   'dry onion soup mix',
#   'cream of mushroom soup',
#   'chili sauce',
#   'onion',
#   'salt and pepper'],
#  ['onion',
#   'margarine',
#   'flour',
#   'sugar',
#   'baking powder',
#   'black pepper',
#   'salt',
#   'whipping cream',
#   'egg'],
#  ['raisins',
#   'unsweetened dried cranberries',
#   'dried apricot',
#   'dried mango',
#   'pumpkin seeds',
#   'almonds',
#   'sunflower seeds',
#   'cayenne'],
#  ['carrot', 'butter', 'light brown sugar', 'water', 'cinnamon', 'honey'],
#  ['granulated sugar', 'white wine vinegar', 'chili peppers', 'garlic cloves'],
#  ['skinless chicken drumsticks',
#   'diced tomatoes',
#   'quick-cooking tapioca',
#   'fresh ginger',
#   'fresh parsley',
#   'garlic cloves',
#   'crushed red pepper flakes',
#   'salt',
#   'cooked brown rice'],
#  ['lime juice',
#   'sugar',
#   'lime-flavored soda water',
#   'maraschino cherry juice',
#   'maraschino cherries',
#   'lime slices'],
#  ['cream cheese',
#   'lemon juice',
#   'crabmeat',
#   'onions',
#   'salt and pepper',
#   'snow peas',
#   'red pepper'],
#  ['water',
#   'fresh broccoli florets',
#   'sweet red pepper',
#   'yellow sweet pepper',
#   'olive oil',
#   'garlic clove',
#   'fresh oregano',
#   'salt',
#   'fresh ground pepper',
#   'tomatoes',
#   'parmesan cheese'],
#  ['mayonnaise',
#   'fresh lime juice',
#   'dried chipotle powder',
#   'orange zest',
#   'sugar',
#   'salmon',
#   'extra virgin olive oil',
#   'corn tortillas',
#   'hass avocado',
#   'cabbage'],
#  ['cranberries',
#   'water',
#   'sugar',
#   'kosher salt',
#   'vanilla bean',
#   'lemon juice'],
#  ['white sugar',
#   'salt',
#   'butter',
#   'evaporated milk',
#   'nuts',
#   'semi-sweet chocolate chips',
#   'chocolate bars',
#   'marshmallow cream'],
#  ['prawns',
#   'olive oil',
#   'onion',
#   'salt',
#   'fresh ground black pepper',
#   'fresh tomato',
#   'garlic',
#   'fresh oregano',
#   'dry white wine',
#   'feta cheese'],
#  ['philadelphia cream cheese',
#   'tasty cheese',
#   'parmesan cheese',
#   'curry powder',
#   'mild paprika'],
#  ['flour', 'salt', 'canola oil', 'skim milk'],
#  ['sushi rice',
#   'water',
#   'kosher salt',
#   'rice vinegar',
#   'vegetable oil',
#   'dark sesame oil',
#   'low sodium soy sauce',
#   'fresh ginger',
#   'garlic clove',
#   'wasabi',
#   'english cucumber',
#   'red onion',
#   'sesame seeds',
#   'nori'],
#  ['ground cumin',
#   'ground coriander',
#   'dried oregano',
#   'ground ginger',
#   'salt',
#   'ground cinnamon',
#   'black pepper',
#   'clove',
#   'corn',
#   'butter'],
#  ['mayonnaise',
#   'sweet pickle relish',
#   'capers',
#   'lemon juice',
#   'hot sauce',
#   'cajun seasoning',
#   'dry mustard',
#   'garlic',
#   'fresh parsley',
#   'dill',
#   'tarragon',
#   'white pepper'],
#  ['cauliflower',
#   'carrots',
#   'red onion',
#   'capers',
#   'fresh parsley',
#   'white wine vinegar',
#   'dijon mustard',
#   'olive oil',
#   'mayonnaise'],
#  ['of fresh mint', 'sugar', 'lemon juice', 'light rum', 'club soda'],
#  ['eggs',
#   'half-and-half',
#   'cheddar cheese',
#   'cooked ham',
#   'green pepper',
#   'onion',
#   'parsley'],
#  ['yellow squash',
#   'onion',
#   'sour cream',
#   'salt',
#   'pepper',
#   'cheddar cheese',
#   'ritz crackers',
#   'butter'],
#  ['butter recipe cake mix',
#   'water',
#   'butter',
#   'eggs',
#   'flour',
#   'sugar',
#   'brown sugar',
#   'vanilla extract',
#   'ground cinnamon'],
#  ['butter',
#   'eggs',
#   'baking powder',
#   'all-purpose flour',
#   'sugar',
#   'milk',
#   'salt',
#   'peppermint candies'],
#  ['berries', 'sugar', 'lemon, juice of'],
#  ['papaya',
#   'fresh pineapple chunks',
#   'bananas',
#   'green apple',
#   'lime, juice of',
#   'canola oil',
#   'onions',
#   'sweet potato',
#   'jalapeno peppers',
#   'madras curry powder',
#   'ginger',
#   'cayenne',
#   'light coconut milk',
#   'raisins',
#   'cashews'],
#  ['garlic cloves',
#   'cumin',
#   'hot paprika',
#   'cilantro',
#   'parsley',
#   'olive oil',
#   'lemon juice',
#   'lemon rind',
#   'swordfish steaks'],
#  ['mixed salad greens',
#   'fresh basil leaf',
#   'turkey breast',
#   'roasted peppers',
#   'kalamata olives',
#   'cherry tomatoes',
#   'avocado',
#   'goat cheese',
#   'balsamic vinegar',
#   'extra virgin olive oil',
#   'salt and black pepper'],
#  ['lean ground beef',
#   'cheese',
#   'carrot',
#   'eggs',
#   'bread',
#   'onion',
#   'milk',
#   'salt',
#   'pepper',
#   'ketchup',
#   'brown sugar',
#   'mustard'],
#  ['pearl barley', 'apples', 'sugar', 'heavy cream', 'lemon juice'],
#  ['butter',
#   'brown sugar',
#   'eggs',
#   'sour cream',
#   'carrot',
#   'coconut',
#   'raisins',
#   'all-purpose flour',
#   'baking soda',
#   'ground cinnamon',
#   'walnuts'],
#  ['baby greens',
#   'red onion',
#   'blue cheese',
#   'pecans',
#   'jelly',
#   'balsamic vinegar',
#   'dijon mustard',
#   'fresh ground pepper',
#   'olive oil',
#   'water'],
#  ['buttermilk',
#   'egg',
#   'butter',
#   'molasses',
#   'cornmeal',
#   'whole wheat flour',
#   'bread flour',
#   'salt',
#   'baking soda',
#   'unsalted sunflower seeds',
#   'active dry yeast'],
#  ['shortening', 'flour', 'salt', 'baking powder', 'boiling water'],
#  ['soy sauce',
#   'wasabi powder',
#   'garlic powder',
#   'tuna steaks',
#   'green beans',
#   'sesame oil',
#   'brown sugar'],
#  ['golden delicious apple',
#   'butter',
#   'ground cinnamon',
#   'sugar',
#   'flour',
#   'milk',
#   'baking powder',
#   'salt',
#   'eggs'],
#  ['ground beef',
#   'romano cheese',
#   'italian seasoned breadcrumbs',
#   'eggs',
#   'salt',
#   'fresh garlic',
#   'garlic',
#   'spanish onion',
#   'celery',
#   'carrot',
#   'olive oil',
#   'fresh italian parsley',
#   'tomatoes with juice',
#   'salt and pepper'],
#  ['eggs',
#   'white sugar',
#   'white flour',
#   'baking powder',
#   'salt',
#   'milk',
#   'butter',
#   'sugar'],
#  ['dried split yellow peas',
#   'water',
#   'ghee',
#   'chili pepper',
#   'cumin seed',
#   'onions',
#   'garlic cloves',
#   'turmeric',
#   'salt',
#   'cilantro'],
#  ['onion powder',
#   'garlic powder',
#   'paprika',
#   'butter',
#   'cream cheese',
#   'chicken broth',
#   'heavy whipping cream',
#   'frozen chopped broccoli',
#   'sharp cheddar cheese'],
#  ['eggs',
#   'sugar',
#   'whipping cream',
#   'sour cream',
#   'flour',
#   'baking powder',
#   'cardamom',
#   'butter'],
#  ['lentils',
#   'red wine vinegar',
#   'dijon mustard',
#   'tomatoes',
#   'green onions',
#   'parsley'],
#  ['ground chicken',
#   'dried chipotle powder',
#   'fresh parsley',
#   'hot sauce',
#   'steak spice'],
#  ['goat cheese',
#   'sun-dried tomato',
#   'garlic cloves',
#   'cream',
#   'chives',
#   'basil',
#   'oregano',
#   'squash blossoms',
#   'egg yolk',
#   'fresh breadcrumb',
#   'oil'],
#  ['whole wheat pasta',
#   'olive oil',
#   'basil',
#   'oregano',
#   'fresh garlic cloves',
#   'crushed red pepper flakes',
#   'romano cheese'],
#  ['dried dates',
#   'soft brown sugar',
#   'crystallized ginger',
#   'butter',
#   'bicarbonate of soda',
#   'self-raising flour',
#   'egg'],
#  ['butter',
#   'onion',
#   'celery',
#   'button mushroom',
#   'flour',
#   'chicken broth',
#   'cream of chicken soup',
#   'sharp cheddar cheese',
#   'curry powder',
#   'dill weed',
#   'dijon mustard',
#   'frozen cooked shrimp',
#   'salt and pepper'],
#  ['cooked chicken breasts',
#   'refried beans',
#   'salsa',
#   'onion',
#   'cheddar cheese',
#   'tortilla chips'],
#  ['extra virgin olive oil',
#   'garlic',
#   'brussels sprout',
#   'sun-dried tomatoes packed in oil',
#   'lemon, zest of',
#   'lemon juice'],
#  ['cabbage',
#   'carrot',
#   'onion',
#   'water',
#   'chicken bouillon',
#   'salt & pepper',
#   'breakfast sausage',
#   'elbow macaroni',
#   'sour cream'],
#  ['crushed pineapple',
#   'lemon peel',
#   'brown rice',
#   'vanilla extract',
#   'brown sugar'],
#  ['chicken breasts',
#   'crushed tomatoes',
#   'chicken broth',
#   'salsa',
#   'canned jalapeno slices',
#   'cumin',
#   'garlic powder',
#   'salt',
#   'flour tortillas',
#   'american cheese',
#   'butter'],
#  ['orange juice',
#   'plain yogurt',
#   'apple cider vinegar',
#   'lecithin granules',
#   'flax seed oil',
#   'ground flax seeds',
#   'oat bran',
#   'cracked wheat',
#   'natural-style peanut butter',
#   'frozen fruit',
#   'banana',
#   'ice cube'],
#  ['fresh kale', 'salt', 'oatmeal', 'cooked bacon'],
#  ['deli turkey',
#   'cream cheese',
#   'orange marmalade',
#   'pecans',
#   'croissants',
#   'whole berry cranberry sauce',
#   'lettuce leaf'],
#  ['strawberries',
#   'red raspberries',
#   'blackberry',
#   'sugar',
#   'freezer jam pectin'],
#  ['self raising flour', 'salt', 'butter', 'caster sugar', 'currants', 'egg'],
#  ['ground beef',
#   'onion',
#   'garlic clove',
#   'bell pepper',
#   'celery',
#   'diced tomatoes',
#   'tomato sauce',
#   'chili powder',
#   'sugar',
#   'flavor enhancer',
#   'salt',
#   'bay leaf',
#   'dried oregano',
#   'dried basil',
#   'hot sauce',
#   'kidney beans'],
#  ['flour',
#   'sugar',
#   'cocoa',
#   'baking powder',
#   'baking soda',
#   'cinnamon',
#   'nutmeg',
#   'allspice',
#   'salt',
#   'carrots',
#   'zucchini',
#   'salad oil',
#   'eggs'],
#  ['kosher salt',
#   'mustard seeds',
#   'whole mixed pickling spice',
#   'celery seed',
#   'onion',
#   'cucumbers',
#   'splenda granular',
#   'white vinegar'],
#  ['vegetable oil',
#   'garlic cloves',
#   'onion',
#   'cauliflower',
#   'water',
#   'lemon juice',
#   'cumin',
#   'turmeric',
#   'cayenne pepper',
#   'salt',
#   'tomatoes',
#   'green chilies'],
#  ['ground beef',
#   'spaghetti sauce',
#   'elbow macaroni',
#   'miracle whip',
#   'shredded cheddar cheese'],
# ...
#   'vanilla',
#   'unsweetened applesauce',
#   'walnuts'],
#  ['pinto beans',
#   'cumin',
#   'dried chili pepper flakes',
#   'paprika',
#   'garlic powder',
#   'onion powder',
#   'oregano',
#   'salt',
#   'olive oil',
#   'onion',
#   'tomatoes',
#   'garlic cloves',
#   'cilantro',
#   'water'],
#  ['chocolate cake mix', 'pumpkin puree', 'water', 'white frosting'],
#  ['vanilla frosting', 'ground cinnamon'],
#  ['oil',
#   'kaffir lime leaves',
#   'chili flakes',
#   'roasted cashews',
#   'fried shallots',
#   'garlic',
#   'salt'],
#  ['prosecco',
#   'sparkling water',
#   'syrup',
#   'mint leaf',
#   'limes',
#   'lime',
#   'ice cube'],
#  ['cumin', 'fennel', 'turmeric powder', 'onions', 'stingray', 'eggplants'],
#  ['black pepper',
#   'ground cayenne pepper',
#   'garlic salt',
#   'celery salt',
#   'basil',
#   'paprika',
#   'salt'],
#  ['fresh white mushrooms',
#   'low-fat parmesan cheese',
#   'breadcrumbs',
#   'parsley',
#   'fresh thyme',
#   'garlic clove',
#   'salt and pepper',
#   'olive oil'],
#  ['garlic cloves',
#   'eggplant',
#   'tahini',
#   'lemon juice',
#   'cumin',
#   'salt and pepper'],
#  ['strawberry cake mix',
#   'diet -up',
#   'egg',
#   'sugar-free strawberry gelatin',
#   'boiling water',
#   'sugar-free instant vanilla pudding mix',
#   'skim milk',
#   'fat-free cool whip',
#   'fresh strawberries'],
#  ['lemons',
#   'salt',
#   'onions',
#   'cider vinegar',
#   'ground mixed spice',
#   'mustard seeds',
#   'sugar',
#   'raisins'],
#  ['vanilla cookies',
#   'peanuts',
#   'butter',
#   'cream cheese',
#   'peanut butter',
#   'powdered sugar',
#   'cool whip',
#   'milk',
#   'instant chocolate pudding mix',
#   'milk chocolate candy bars'],
#  ['flounder fillets',
#   'tomatoes',
#   'olive oil',
#   'garlic cloves',
#   'onion',
#   'fresh oregano',
#   'dry white wine',
#   'salt',
#   'fresh ground black pepper'],
#  ['orange juice',
#   'extra virgin olive oil',
#   'rice vinegar',
#   'sesame seeds',
#   'honey',
#   'salt',
#   'napa cabbage',
#   'cilantro leaf'],
#  ['albacore tuna in water',
#   'cannellini beans',
#   'olive oil',
#   'red wine vinegar',
#   'onion',
#   'celery',
#   'grape tomatoes',
#   'stuffed green olive',
#   'dried basil',
#   'dried dill weed',
#   'salt and pepper'],
#  ['olive oil',
#   'onion',
#   'garlic cloves',
#   'beets',
#   'red wine vinegar',
#   'tomato paste',
#   'vegetable broth',
#   'heavy cream'],
#  ['boneless skinless chicken breasts',
#   'all-purpose flour',
#   'dried oregano leaves',
#   'garlic powder',
#   'paprika',
#   'salt',
#   'pepper',
#   'olive oil',
#   'fresh mushrooms',
#   'white wine',
#   'sour cream',
#   'tomato paste',
#   'white rice'],
#  ['butter',
#   'fresh basil',
#   'fresh parsley',
#   'white wine vinegar',
#   'dry breadcrumbs',
#   'fresh lemon juice',
#   'white pepper',
#   'shrimp',
#   'white wine',
#   'lemon slice'],
#  ['boneless chicken thighs',
#   'olive oil',
#   'onion',
#   'celery rib',
#   'green pepper',
#   'garlic cloves',
#   'green olives',
#   'tomatoes',
#   'beef broth',
#   'chili sauce',
#   'bay leaf',
#   'thyme leaves',
#   'parsley flakes',
#   'brown sugar',
#   'salt',
#   'cayenne pepper',
#   'dry sherry',
#   'ham'],
#  ['eggs',
#   'milk',
#   'salt',
#   'pepper',
#   'spring onions',
#   'chilies',
#   'ginger',
#   'ghee',
#   'turmeric',
#   'coriander',
#   'tomatoes',
#   'cumin'],
#  ['popped popcorn',
#   'mixed nuts',
#   'pretzels',
#   'butter',
#   'worcestershire sauce',
#   'seasoned pepper',
#   'garlic powder'],
#  ['shallot', 'plain nonfat yogurt', 'greek yogurt'],
#  ['unsalted butter',
#   'light brown sugar',
#   'granulated sugar',
#   'pure vanilla extract',
#   'extra-large eggs',
#   'unsweetened cocoa',
#   'flour',
#   'baking soda',
#   'kosher salt',
#   'white chocolate'],
#  ['olive oil',
#   'onion',
#   'celery',
#   'potatoes',
#   'chicken broth',
#   'cheese',
#   '% low-fat milk',
#   'herbs'],
#  ['tomato juice',
#   'lemon juice',
#   'worcestershire sauce',
#   'tabasco sauce',
#   'salt',
#   'pepper',
#   'vodka',
#   'celery'],
#  ['plain yogurt',
#   'sour cream',
#   'mayonnaise',
#   'garlic cloves',
#   'paprika',
#   'salt',
#   'pepper',
#   'fresh chives'],
#  ['celery ribs', 'cheese whiz', 'raisins'],
#  ['cooked bacon',
#   'onion',
#   'celery',
#   'carrots',
#   'potato',
#   'baby clams',
#   'water',
#   'clam juice',
#   'worcestershire sauce',
#   'salt',
#   'black pepper',
#   'bay leaf',
#   'all-purpose flour',
#   'evaporated milk',
#   'green pepper'],
#  ['plain flour',
#   'self raising flour',
#   'bicarbonate of soda',
#   'mixed spice',
#   'cinnamon',
#   'brown sugar',
#   'nuts',
#   'eggs',
#   'carrots',
#   'banana',
#   'vegetable oil'],
#  ['granulated sugar',
#   'powdered sugar',
#   'butter',
#   'vegetable oil',
#   'vanilla extract',
#   'eggs',
#   'all-purpose flour',
#   'baking soda',
#   'cream of tartar',
#   'salt'],
#  ['fruit cocktail',
#   'crushed pineapple',
#   'cool whip',
#   'instant pistachio pudding mix',
#   'walnuts',
#   'maraschino cherry'],
#  ['boiling water',
#   'sugar-free cranberry flavor gelatin',
#   'water',
#   'ice cube',
#   'low-fat vanilla yogurt',
#   'vanilla',
#   'fat-free whipped topping',
#   'kiwi fruit'],
#  ['water',
#   'sugar',
#   'frozen unsweetened strawberries',
#   'rhubarb',
#   'strawberry gelatin',
#   'lemon juice',
#   'ginger ale',
#   'carbonated lemon-lime beverage'],
#  ['water',
#   'tomato sauce',
#   'cooked ground beef',
#   'salt',
#   'olive oil',
#   'dried oregano',
#   'romano cheese',
#   'rigatoni pasta'],
#  ['chili powder',
#   'dried oregano',
#   'ground cumin',
#   'sweet potato',
#   'black beans',
#   'garlic cloves',
#   'onion',
#   'jalapeno pepper',
#   'green pepper',
#   'frozen corn',
#   'fresh lime juice',
#   'cilantro',
#   'monterey jack cheese'],
#  ['dry white wine',
#   'blue curacao',
#   'fresh lemon juice',
#   'simple syrup',
#   'oranges',
#   'pineapple chunk',
#   'carbonated lemon-lime beverage'],
#  ['fennel seed',
#   'szechuan peppercorns',
#   'star anise',
#   'ground cinnamon',
#   'ground cloves'],
#  ['butter',
#   'eggs',
#   'vanilla extract',
#   'sugar',
#   'all-purpose flour',
#   'peanut butter and milk chocolate chips',
#   'pecans',
#   'unbaked -inch pie crust',
#   'sweetened whipped cream'],
#  ['cream cheese',
#   'eggs',
#   'pure vanilla extract',
#   'sugar',
#   'white chocolate',
#   'fresh fruit'],
#  ['butterscotch chips',
#   'heavy whipping cream',
#   'butter',
#   'vanilla',
#   'powdered sugar'],
#  ['olive oil',
#   'onion',
#   'minced garlic clove',
#   'basil',
#   'oregano',
#   'red pepper powder',
#   'tomatoes',
#   'cooked spaghetti',
#   'balsamic vinegar'],
#  ['ground beef',
#   'plain breadcrumbs',
#   'onion',
#   'worcestershire sauce',
#   'egg',
#   'salt',
#   'pepper',
#   'milk',
#   'crisco',
#   'parsley',
#   'chili sauce',
#   'currant jelly'],
#  ['low-fat vanilla yogurt',
#   'cool whip free',
#   'apple',
#   'strawberries',
#   'bananas',
#   'grapes',
#   'low-fat granola'],
#  ['nonstick cooking spray',
#   'oatmeal',
#   'chocolate whey protein powder',
#   'flax seeds',
#   'nonfat dry milk powder',
#   'natural-style peanut butter',
#   'water',
#   'vanilla',
#   'raisins'],
#  ['semolina flour',
#   'all-purpose flour',
#   'vital wheat gluten',
#   'salt',
#   'warm water'],
#  ['salmon steaks',
#   'soy sauce',
#   'marsala',
#   'lemon juice',
#   'sugar',
#   'garlic',
#   'scallions'],
#  ['vidalia onions',
#   'unsalted butter',
#   'cheddar cheese',
#   'mayonnaise',
#   'hot sauce',
#   'garlic clove'],
#  ['whole wheat fusilli',
#   'walnut pieces',
#   'feta cheese',
#   'red onion',
#   'baby spinach leaves',
#   'walnut oil',
#   'red wine vinegar',
#   'garlic clove',
#   'dijon mustard',
#   'salt and pepper'],
#  ['red onion',
#   'red wine vinegar',
#   'cherry tomatoes',
#   'fine sea salt',
#   'red kidney beans',
#   'extra virgin olive oil'],
#  ['banana liqueur', 'galliano', 'cream', 'ice'],
#  ['water',
#   'unsweetened orange juice',
#   'rolled oats',
#   'oat bran',
#   'ground cinnamon',
#   'cardamom',
#   'dried cranberries',
#   'maple syrup',
#   'honey',
#   'brown sugar'],
#  ['lime juice', 'honey', 'watermelon'],
#  ['unsweetened chocolate',
#   'butter',
#   'strong coffee',
#   'sugar',
#   'egg',
#   'vanilla extract',
#   'flour',
#   'baking soda',
#   'salt'],
#  ['butter',
#   'cream cheese',
#   'vanilla extract',
#   "confectioners' sugar",
#   'sweetened flaked coconut',
#   'ground cinnamon'],
#  ['gin', 'blue curacao', 'lemon juice'],
#  ['boneless chicken breasts',
#   'onion',
#   'lemon juice',
#   'pepper',
#   'salt',
#   'chicken stock',
#   'pomegranate molasses',
#   'walnuts',
#   'oil'],
#  ['red potatoes',
#   'olive oil',
#   'salt',
#   'thyme',
#   'basil',
#   'oregano',
#   'rosemary',
#   'pepper',
#   'garlic powder'],
#  ['hass avocadoes', 'lime, juice and zest of', 'garlic cloves'],
#  ['unbaked pie shell',
#   'sugar-free instant vanilla pudding mix',
#   'milk',
#   'coconut extract',
#   'coconut flakes',
#   'cool whip topping'],
#  ['yams',
#   'peach slices',
#   'granulated sugar',
#   'eggs',
#   'vanilla extract',
#   'whole milk',
#   'unsalted butter',
#   'all-purpose flour',
#   'dark brown sugar',
#   'pecans',
#   'dried cranberries'],
#  ['boneless skinless chicken breasts',
#   'cream of chicken soup',
#   'chicken broth',
#   'flour',
#   'butter',
#   'colby-monterey jack cheese',
#   'fajita seasoning mix',
#   'red cayenne pepper',
#   'diced onion',
#   'green bell pepper'],
#  ['butter', 'salt', 'milk', 'eggs', 'flour'],
#  ['potatoes',
#   'carrots',
#   'onion',
#   'frozen peas',
#   'seitan',
#   'flour',
#   'oil',
#   'soymilk',
#   'vegetable stock',
#   'whole wheat flour',
#   'unbleached white flour',
#   'salt',
#   'water'],
#  ['clams',
#   'bacon',
#   'onion',
#   'green bell pepper',
#   'red bell pepper',
#   'seasoned bread crumbs',
#   'garlic powder',
#   'seasoning salt',
#   'parsley'],
#  ['fat free cream cheese',
#   'skim milk',
#   'sugar-free instant vanilla pudding mix',
#   'ladyfingers',
#   'fat-free whipped topping',
#   'strawberries',
#   'water'],
#  ['all-purpose flour',
#   'pumpkin pie spice',
#   'baking powder',
#   'baking soda',
#   'salt',
#   'butter',
#   'sugar',
#   "libby's canned pumpkin",
#   'eggs',
#   'vanilla',
#   'semi-sweet chocolate chips',
#   'walnuts',
#   'powdered sugar',
#   'milk'],
#  ['diced tomatoes',
#   'ortega green chilie',
#   'green onion',
#   'yellow onions',
#   'cilantro',
#   'jalapeno pepper',
#   'sweet pepper',
#   'garlic',
#   'salt'],
#  ['all-purpose flour',
#   'unsweetened cocoa powder',
#   'vegetable oil',
#   'milk',
#   'granulated sugar',
#   'light brown sugar',
#   'baking powder',
#   'salt'],
#  ['frozen hash brown potatoes',
#   'ham',
#   'cream of potato soup',
#   'sour cream',
#   'sharp cheddar cheese',
#   'cheese'],
#  ['mashed potatoes', 'parmesan cheese', 'eggs', 'sharp cheddar cheese'],
#  ['chicken broth',
#   'vanilla',
#   'butternut squash',
#   'butter',
#   'white onion',
#   'arborio rice',
#   'white wine',
#   'parmesan cheese',
#   'salt'],
#  ['fresh asparagus',
#   'refrigerated crescent dinner rolls',
#   'monterey jack cheese',
#   'bacon bits',
#   'green onion'],
#  ['carrots', 'onions', 'pepper', 'sugar', 'accent seasoning', 'bacon'],
#  ['amaretto', 'dark creme de cacao', 'strawberry cream liqueur', 'milk'],
#  ['egg yolk',
#   'blackstrap molasses',
#   'vegetable oil',
#   'vanilla extract',
#   'whole wheat pastry flour',
#   'soy flour',
#   'wheat germ',
#   'dry milk'],
#  ['bisquick baking mix',
#   'milk',
#   'cheddar cheese',
#   'margarine',
#   'garlic powder'],
#  ['butter',
#   'milk',
#   'vanilla',
#   'salt',
#   "confectioners' sugar",
#   'bittersweet chocolate squares'],
#  ['nonstick cooking spray',
#   'all-purpose flour',
#   'whole wheat flour',
#   'baking powder',
#   'ground nutmeg',
#   'salt',
#   'baking soda',
#   'egg substitute',
#   'pumpkin',
#   'sugar',
#   'splenda sugar substitute',
#   'honey',
#   'cooking oil',
#   'unsweetened applesauce',
#   'orange peel',
#   'orange juice',
#   'walnuts',
#   'pitted dates'],
#  ['head of cabbage',
#   'carrots',
#   'zucchini',
#   'garlic cloves',
#   'extra virgin olive oil',
#   'low-sodium teriyaki sauce',
#   'black pepper'],
#  ['chile pepper jam',
#   'lime juice',
#   'fish sauce',
#   'palm sugar',
#   'chicken stock',
#   'pumpkin',
#   'vegetable oil',
#   'prawns',
#   'baby spinach leaves',
#   'red onion'],
#  ['bacon', 'diced tomato', 'onion', 'black pepper', 'spaghetti', 'salt'],
#  ['hot chocolate powder', 'hot water', 'half-and-half cream'],
#  ['flour',
#   'water',
#   'brown sugar',
#   'sugar',
#   'salt',
#   'vanilla extract',
#   'baking cocoa',
#   'oil',
#   'baking powder',
#   'nuts',
#   'semisweet vegan chocolate chips'],
#  ['onion',
#   'ginger',
#   'boneless chicken',
#   'oil',
#   'curry powder',
#   'coconut milk',
#   'water',
#   'tomato paste'],
#  ['vegetable stock',
#   'water',
#   'quinoa',
#   'pearl barley',
#   'red potatoes',
#   'carrots',
#   'parsnip',
#   'green onions',
#   'leek',
#   'cabbage'],
#  ['olive oil',
#   'leek',
#   'baby portabella mushrooms',
#   'garlic cloves',
#   'marsala wine',
#   'reduced-sodium fat-free chicken broth',
#   'cornstarch'],
#  ['fat-free mayonnaise', 'horseradish', 'dill'],
#  ['neufchatel cheese',
#   'icing sugar',
#   'wasabi peas',
#   'pimento-stuffed green olives',
#   'worchestershire sauce',
#   'crushed pineapple',
#   'nutmeg',
#   'rye cocktail bread'],
#  ['salad dressing', 'italian salad dressing'],
#  ['olive oil',
#   'spanish onion',
#   'garlic cloves',
#   'turmeric',
#   'cumin powder',
#   'quinoa',
#   'lime, juice and zest of',
#   'slivered almonds',
#   'currants',
#   'fresh coriander',
#   'lime wedge'],
#  ['light cream',
#   'sweetened condensed milk',
#   'scotch whisky',
#   'instant coffee',
#   'chocolate syrup',
#   'vanilla extract',
#   'almond extract'],
#  ['raspberries',
#   'granulated sugar',
#   'lemon juice',
#   'liquid fruit pectin',
#   'chambord raspberry liquor'],
#  ['all-purpose flour',
#   'sugar',
#   'baking powder',
#   'milk',
#   'vanilla',
#   'peanut butter',
#   'unsweetened cocoa powder',
#   'boiling water',
#   'vanilla ice cream',
#   'chocolate fudge topping',
#   'peanuts'],
#  ['cider vinegar',
#   'dijon mustard',
#   'honey',
#   'salt',
#   'cracked black pepper',
#   'olive oil',
#   'water',
#   'shallot',
#   'sunflower seeds',
#   'baby spinach',
#   'apple',
#   'roquefort cheese'],
#  ['black beans',
#   'corn kernels',
#   'cherry tomatoes',
#   'green onions',
#   'sweet red pepper',
#   'fresh coriander',
#   'olive oil',
#   'red wine vinegar',
#   'garlic clove',
#   'salt',
#   'cumin powder',
#   'granulated sugar',
#   'black pepper',
#   'hot pepper sauce'],
#  ['creamy italian dressing',
#   'broccoli',
#   'cauliflower',
#   'fresh mushrooms',
#   'carrot',
#   'black olives',
#   'cherry tomatoes',
#   'spaghetti noodles',
#   'parmesan cheese',
#   'bacon bits'],
#  ['apple juice', 'lemon juice', 'soda water', 'lemon, rind of'],
#  ['ground beef',
#   'breadcrumbs',
#   'onion soup mix',
#   'egg',
#   'worcestershire sauce',
#   'oxo beef cube'],
#  ['fresh spinach',
#   'parmesan cheese',
#   'onions',
#   'light cream',
#   'butter',
#   'salt & fresh ground pepper',
#   'cracker crumb'],
#  ['boneless skinless chicken breast halves',
#   'all-purpose flour',
#   'salt',
#   'ground black pepper',
#   'butter',
#   'stewed tomatoes',
#   'water',
#   'brown sugar',
#   'distilled white vinegar',
#   'worcestershire sauce',
#   'chili powder',
#   'mustard powder',
#   'celery seed',
#   'garlic clove',
#   'hot pepper sauce'],
#  ['boneless skinless chicken breasts',
#   'celery',
#   'onion',
#   'green pepper',
#   'garlic',
#   'fresh mushrooms',
#   'green olives',
#   'italian seasoning',
#   'crushed red pepper flakes',
#   'blue cheese',
#   'low-carb spaghetti sauce',
#   'cabernet sauvignon wine'],
#  ['cake',
#   'spice cake mix',
#   'crushed pineapple',
#   'eggs',
#   'orange extract',
#   'powdered sugar',
#   'water'],
#  ['flour',
#   'sugar',
#   'cocoa',
#   'baking soda',
#   'salt',
#   'water',
#   'vegetable oil',
#   'vinegar',
#   'vanilla',
#   'chocolate chips'],
#  ['hot dog buns', 'butter', 'eggs', 'vanilla', 'granulated sugar', 'milk'],
#  ['cream cheese',
#   'butter',
#   'milk',
#   'frozen chopped spinach',
#   'fresh parsley',
#   'walnuts',
#   'vegetable oil',
#   'fresh lemon juice',
#   'garlic',
#   'dried basil',
#   'dried oregano',
#   'parmesan cheese',
#   'french bread'],
#  ['french style green beans',
#   'cut green beans',
#   '% fat-free cream of mushroom soup',
#   'mushroom pieces',
#   'nonfat milk',
#   'worcestershire sauce',
#   'black pepper',
#   'onion'],
#  ['pizza crusts',
#   'olive oil',
#   'basil',
#   'rosemary',
#   'garlic',
#   'kosher salt',
#   'tomatoes and green chilies',
#   'parmesan cheese'],
#  ['chicken',
#   'smoked sausage',
#   'celery & leaves',
#   'carrot',
#   'onion',
#   'stewed tomatoes',
#   'water',
#   'chicken bouillon granules',
#   'dried thyme leaves',
#   'frozen cut okra',
#   'cooked rice',
#   'red pepper sauce'],
#  ['mostaccioli pasta',
#   'cauliflower',
#   'garlic cloves',
#   'green onions',
#   'butter',
#   'vegetable oil',
#   'seasoned bread crumbs',
#   'salt',
#   'fresh ground black pepper',
#   'parmesan cheese'],
#  ...]

# %%
def get_number_of_ingredient_used(ingredient_list,text):
    ing_count = 0
    for ing in ingredient_list :
        if ing in text :
            ing_count+=1
    ing_frac = ing_count/len(ingredient_list)
    return ing_frac
ing_frac = [get_number_of_ingredient_used(x[1][i],x[2][i]) for i in range(len(x[1]))]
print(sum(ing_frac)/len(ing_frac))
# Out:
# 0.18761455200521684

# %%
0.16/0.18
# Out:
# 0.888888888888889

# %%
def get_number_of_ingredient_used2(ingredient_list,text):
    ing_count = 0
    total_words = 0
    for ing in ingredient_list :
        ings = ing.split(' ')
        total_words +=len(ings) 
        for i in ings :
            if i in text :
                ing_count+=1
                
    ing_frac = ing_count/total_words
    return ing_frac
ing_frac = [get_number_of_ingredient_used2(x[1][i],x[3][i]) for i in range(len(x[1]))]
print(sum(ing_frac)/len(ing_frac))
# Out:
# 0.27725680561784927
